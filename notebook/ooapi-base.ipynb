# %%
# %pip install requests python-dotenv

# %%
import requests
import base64
import json
from datetime import datetime, timedelta
from time import sleep
from dotenv import load_dotenv
import os
from pprint import pprint

load_dotenv()
# Out:
# True

# %%
BASE_URL = "https://apigateway-ota.osiris-link.nl/api/tue/acc/ords/ooapi/v5"
TIMEOUT = 60

API_KEY = os.getenv("API_KEY")

CONSUMER = "eduxchange"
ALLIANCE = "ewuu"

# %%
print("API KEY AUTHENTICATION TEST")

headers = {
    "api-key": API_KEY
}

params = {
    "educationSpecificationType": "program",
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/education-specifications"

response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)

print(f"\nStatus Code: {response.status_code}")

if response.status_code == 200:
    print("Authentication successful!")
    data = response.json()
    print(f"Retrieved {len(data.get('items', []))} education specifications")
else:
    print(f"Authentication failed: {response.text}")
# Out:
# API KEY AUTHENTICATION TEST
#
# Status Code: 200
# Authentication successful!
# Retrieved 10 education specifications

# %%
print("GET /education-specifications")

headers = {
    "api-key": API_KEY
}

params = {
    "educationSpecificationType": "program",
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/education-specifications"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)

if response.status_code == 200:
    data = response.json()
    
    if data.get("items"):
        print(json.dumps(data["items"], indent=2))
else:
    print(f"Failed: {response.status_code} - {response.text}")
# Out:
# GET /education-specifications
# [
#   {
#     "educationSpecificationId": "39b4a603-deaa-4d88-951e-e2078bc7cede",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "39b4a603-deaa-4d88-951e-e2078bc7cede"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "AI and Digital Innovation"
#       },
#       {
#         "language": "en-GB",
#         "value": "AI and Digital Innovation"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "AI and Digital Innovation"
#       },
#       {
#         "language": "en-GB",
#         "value": "AI and Digital Innovation"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "9d730d2a-800d-4273-90ab-55ed59523d25",
#     "consumers": [],
#     "validFrom": "2023-09-15"
#   },
#   {
#     "educationSpecificationId": "c393e599-2f4a-4b12-950e-56aed32bb4d7",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "c393e599-2f4a-4b12-950e-56aed32bb4d7"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Analytics for Transport and Mobility"
#       },
#       {
#         "language": "en-GB",
#         "value": "Analytics for Transport and Mobility"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Analytics for Transport and Mobility"
#       },
#       {
#         "language": "en-GB",
#         "value": "Analytics for Transport and Mobility"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "fb7e2215-0742-40e8-a1e3-5bf3dee9e252",
#     "consumers": [],
#     "validFrom": "2023-09-15"
#   },
#   {
#     "educationSpecificationId": "2c72b16b-f194-4bee-bc9d-fe361dc072f7",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "2c72b16b-f194-4bee-bc9d-fe361dc072f7"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Applied Physics"
#       },
#       {
#         "language": "en-GB",
#         "value": "Applied Physics"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Applied Physics"
#       },
#       {
#         "language": "en-GB",
#         "value": "Applied Physics"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "c922fcff-23dc-4b33-8fcc-5db37631c9a3",
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   },
#   {
#     "educationSpecificationId": "7b3e2ed3-d91b-42f2-83cb-fce68e74d792",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "7b3e2ed3-d91b-42f2-83cb-fce68e74d792"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Architecture, Building and Planning"
#       },
#       {
#         "language": "en-GB",
#         "value": "Architecture, Building and Planning"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Architecture, Building and Planning"
#       },
#       {
#         "language": "en-GB",
#         "value": "Architecture, Building and Planning"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "c2748859-56d1-412c-a8b7-29b1a6ffe3da",
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   },
#   {
#     "educationSpecificationId": "a2ee6122-a968-4f8f-a9e9-9718560e88a6",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "a2ee6122-a968-4f8f-a9e9-9718560e88a6"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence & Engineering Systems"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence & Engineering Systems"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence & Engineering Systems"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence & Engineering Systems"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "6ad8e548-f126-4e66-89d2-9ecd31aad05b",
#     "consumers": [],
#     "validFrom": "2022-09-01"
#   },
#   {
#     "educationSpecificationId": "291d8045-822b-4b77-86fc-65e4cb5d3515",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "291d8045-822b-4b77-86fc-65e4cb5d3515"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence Engineering Systems E"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence Engineering Systems E"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence Engineering Systems E"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence Engineering Systems E"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "ebc4a08a-b8de-4696-9252-02bf9ab817ed",
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   },
#   {
#     "educationSpecificationId": "10292f8d-c070-464a-95ed-1a1a19386203",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "10292f8d-c070-464a-95ed-1a1a19386203"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence Engineering Systems W"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence Engineering Systems W"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Artificial Intelligence Engineering Systems W"
#       },
#       {
#         "language": "en-GB",
#         "value": "Artificial Intelligence Engineering Systems W"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "b0027f7d-d7a0-448e-a809-ae1efa26adee",
#     "consumers": [],
#     "validFrom": "2020-09-10",
#     "validTo": "2025-08-31"
#   },
#   {
#     "educationSpecificationId": "f0aa95a9-27b9-477f-bf4d-992b5c73bc71",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "f0aa95a9-27b9-477f-bf4d-992b5c73bc71"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Automotive Technology"
#       },
#       {
#         "language": "en-GB",
#         "value": "Automotive Technology"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Automotive Technology"
#       },
#       {
#         "language": "en-GB",
#         "value": "Automotive Technology"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "master",
#     "sector": "university education",
#     "parent": "055d1086-caa1-4598-82f4-5924ef56f84a",
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   },
#   {
#     "educationSpecificationId": "4edcb049-4e2c-4ac2-bd21-c814afde40d8",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "4edcb049-4e2c-4ac2-bd21-c814afde40d8"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "Automotive Technology"
#       },
#       {
#         "language": "en-GB",
#         "value": "Automotive Technology"
#       }
#     ],
#     "description": [
#       {
#         "language": "nl-NL",
#         "value": "Automotive Technology"
#       },
#       {
#         "language": "en-GB",
#         "value": "Automotive Technology"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "bachelor",
#     "sector": "university education",
#     "parent": "953d95f3-b4e8-4630-9248-9ea3f74b9a15",
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   },
#   {
#     "educationSpecificationId": "81c4bcb3-109c-4486-85f8-5bb4d84575e3",
#     "primaryCode": {
#       "codeType": "uuid",
#       "code": "81c4bcb3-109c-4486-85f8-5bb4d84575e3"
#     },
#     "educationSpecificationType": "program",
#     "name": [
#       {
#         "language": "nl-NL",
#         "value": "B Biomedische Technologie"
#       },
#       {
#         "language": "en-GB",
#         "value": "B Biomedical Engineering"
#       }
#     ],
#     "formalDocument": "diploma",
#     "level": "bachelor",
#     "sector": "university education",
#     "children": [
#       "58b10808-12a0-4aa9-8a0d-7050bc250eeb",
#       "a0fcdf1d-23f8-4fd3-8d3c-e30cd493a112",
#       "9541b80a-01ec-45ef-a1c1-afef63649bdf"
#     ],
#     "consumers": [],
#     "validFrom": "2020-09-10"
#   }
# ]

# %%
print("GET /education-specifications/{id}")

headers = {
    "api-key": API_KEY
}

params = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/education-specifications"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)
data = response.json()

if data.get("items") and len(data["items"]) > 0:
    spec_id = data["items"][0]["educationSpecificationId"]
    print(f"Testing with spec ID: {spec_id}")
    pprint(data["items"][0])
    
else:
    print("No specs available")
# Out:
# GET /education-specifications/{id}
# Testing with spec ID: 39b4a603-deaa-4d88-951e-e2078bc7cede
# {'consumers': [],
#  'description': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#                  {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#  'educationSpecificationId': '39b4a603-deaa-4d88-951e-e2078bc7cede',
#  'educationSpecificationType': 'program',
#  'formalDocument': 'diploma',
#  'level': 'master',
#  'name': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#           {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#  'parent': '9d730d2a-800d-4273-90ab-55ed59523d25',
#  'primaryCode': {'code': '39b4a603-deaa-4d88-951e-e2078bc7cede',
#                  'codeType': 'uuid'},
#  'sector': 'university education',
#  'validFrom': '2023-09-15'}

# %%
print("GET /courses")

headers = {
    "api-key": API_KEY
}

params = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/courses"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)

if response.status_code == 200:
    data = response.json()
    print(f"Success! Found {len(data.get('items', []))} courses")
    
    if data.get('items'):
        for i, course in enumerate(data['items'], 1):
            pprint(data['items'])
            break
else:
    print(f"Failed: {response.status_code} - {response.text}")
# Out:
# GET /courses
# Success! Found 10 courses
# [{'abbreviation': '0HM130',
#   'addresses': [],
#   'admissionRequirements': [{'language': 'nl-NL',
#                              'value': 'Je moet voldoen aan één van de '
#                                       'onderstaande verzamelingen met eisen\n'
#                                       '- Verzameling 1\n'
#                                       '- Bachelor of Science (BSc) afgerond\n'
#                                       '- Verzameling 2\n'
#                                       '- Schakelprogramma afgerond'},
#                             {'language': 'en-GB',
#                              'value': 'You must meet one of the following '
#                                       'collections of requirements\n'
#                                       '- Collection 1\n'
#                                       '- Completed Final examination Bsc '
#                                       'program\n'
#                                       '- Collection 2\n'
#                                       '- Completed Pre-Master'}],
#   'assessment': [],
#   'consumers': [{'alliances': [{'name': 'EWUU',
#                                 'selection': False,
#                                 'theme': '',
#                                 'type': 'broadening',
#                                 'visibleForOwnStudents': False}],
#                  'consumerKey': 'eduxchange'}],
#   'courseId': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#   'description': [{'language': 'nl-NL',
#                    'value': 'The course consists of 10 lectures.   \n'
#                             'The lectures cover core topics in cognition '
#                             '(representations, attention, memory, language, '
#                             'categorization, creativity and AI, and '
#                             'similarity). These lecture will be accompanied by '
#                             'weekly assignments where students experience '
#                             'basic experimental paradigms in cognitive '
#                             'psychology, such as the Simon Effect, Working '
#                             'Memory Tasks, and Similarity experiments. '
#                             'Students will perform these experiments, reflect '
#                             'upon their underlying mechanisms and link them to '
#                             'theories in the reading material, and translate '
#                             'the relevance of these mechanisms to facets of '
#                             'human-technology interaction. Lectures are also '
#                             'accompanied by applied assignments providing '
#                             'advice for a (hypothetical) behavioral insight '
#                             'team that used knowledge from cognitive '
#                             'psychology to address a societal problem.'},
#                   {'language': 'en-GB',
#                    'value': 'The course consists of 10 lectures.   \n'
#                             'The lectures cover core topics in cognition '
#                             '(representations, attention, memory, language, '
#                             'categorization, creativity and AI, and '
#                             'similarity). These lecture will be accompanied by '
#                             'weekly assignments where students experience '
#                             'basic experimental paradigms in cognitive '
#                             'psychology, such as the Simon Effect, Working '
#                             'Memory Tasks, and Similarity experiments. '
#                             'Students will perform these experiments, reflect '
#                             'upon their underlying mechanisms and link them to '
#                             'theories in the reading material, and translate '
#                             'the relevance of these mechanisms to facets of '
#                             'human-technology interaction. Lectures are also '
#                             'accompanied by applied assignments providing '
#                             'advice for a (hypothetical) behavioral insight '
#                             'team that used knowledge from cognitive '
#                             'psychology to address a societal problem.'}],
#   'duration': '',
#   'enrollment': [],
#   'ext': {},
#   'fieldsOfStudy': '',
#   'firstStartDate': '',
#   'learningOutcomes': [[{'language': 'nl-NL',
#                          'value': '\n'
#                                   'The goal of the course is to gain a further '
#                                   'understanding of the basic research '
#                                   'questions and methodologies of cognitive '
#                                   'science.  \n'
#                                   '\n'
#                                   '\n'
#                                   'After the course, students will be able '
#                                   'to:\n'
#                                   '- interpret empirical findings in cognitive '
#                                   'science in light of theoretical ideas,\n'
#                                   '- interpret classical findings and '
#                                   'paradigms in cognitive science,\n'
#                                   '- explain empirical findings from different '
#                                   'theoretical perspectives,\n'
#                                   '- apply scientific knowledge in a technical '
#                                   'domain and for government policy,\n'
#                                   '- critically evaluate ongoing scientific '
#                                   'research.\n'
#                                   '\n'},
#                         {'language': 'en-GB',
#                          'value': '\n'
#                                   'The goal of the course is to gain a further '
#                                   'understanding of the basic research '
#                                   'questions and methodologies of cognitive '
#                                   'science.  \n'
#                                   '\n'
#                                   '\n'
#                                   'After the course, students will be able '
#                                   'to:\n'
#                                   '- interpret empirical findings in cognitive '
#                                   'science in light of theoretical ideas,\n'
#                                   '- interpret classical findings and '
#                                   'paradigms in cognitive science,\n'
#                                   '- explain empirical findings from different '
#                                   'theoretical perspectives,\n'
#                                   '- apply scientific knowledge in a technical '
#                                   'domain and for government policy,\n'
#                                   '- critically evaluate ongoing scientific '
#                                   'research.\n'
#                                   '\n'}]],
#   'level': 'master',
#   'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642484&taal=nl',
#   'modeOfDelivery': [],
#   'name': [{'language': 'nl-NL', 'value': 'Advanced cognition'},
#            {'language': 'en-GB', 'value': 'Advanced cognition'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#                   'codeType': 'uuid'},
#   'qualificationRequirements': [],
#   'resources': [' No book. Articles and chapters are provided by the '
#                 'lecturer.'],
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#   'teachingLanguage': 'eng',
#   'validFrom': '',
#   'validTo': ''},
#  {'abbreviation': '0HM150',
#   'addresses': [],
#   'admissionRequirements': [{'language': 'nl-NL',
#                              'value': 'Je moet voldoen aan één van de '
#                                       'onderstaande verzamelingen met eisen\n'
#                                       '- Verzameling 1\n'
#                                       '- Bachelor of Science (BSc) afgerond\n'
#                                       '- Verzameling 2\n'
#                                       '- Schakelprogramma afgerond'},
#                             {'language': 'en-GB',
#                              'value': 'You must meet one of the following '
#                                       'collections of requirements\n'
#                                       '- Collection 1\n'
#                                       '- Completed Final examination Bsc '
#                                       'program\n'
#                                       '- Collection 2\n'
#                                       '- Completed Pre-Master'}],
#   'assessment': [],
#   'consumers': [{'alliances': [{'name': 'EWUU',
#                                 'selection': False,
#                                 'theme': '',
#                                 'type': 'broadening',
#                                 'visibleForOwnStudents': False}],
#                  'consumerKey': 'eduxchange'}],
#   'courseId': 'c2af7f53-6cf6-4cd2-870d-b91d6ba001e0',
#   'description': [{'language': 'nl-NL',
#                    'value': '\n'
#                             'Cognitive engineering is a multidisciplinary '
#                             'endeavour concerned with the analysis, design, '
#                             'and evaluation of complex systems of people and '
#                             'technology. It combines knowledge and experience '
#                             'from cognitive science, human factors, '
#                             'human-computer interaction design, and systems '
#                             'engineering. The traditional focus of cognitive '
#                             'engineering has been on understanding the '
#                             'cognitive demands imposed by complex work '
#                             'environments, and designing systems that will '
#                             'help create an optimal sociotechnical ecosystem. '
#                             'However, as ICT is increasingly moving beyond the '
#                             'workplace, into private and public realms, and '
#                             'ICT systems are embedded into everyday objects '
#                             'and environments, the scope of the course will '
#                             'include new application domains (e.g., in home, '
#                             'healthcare, or automotive contexts), new '
#                             'interaction styles and paradigms (e.g., '
#                             'ubiquitous computing, gesture-based computing, '
#                             'affective computing) as well new theoretical '
#                             'frameworks that are required to understand '
#                             "humans' co-adaptive relationship with technology "
#                             '(e.g., embodied cognition, extended mind, '
#                             'distributed cognition).  \n'
#                             '\n'
#                             'In this course, you will be introduced to the '
#                             'basic principles of cognitive systems engineering '
#                             'and obtain an appreciation of the main trends and '
#                             'developments in interface design "beyond the '
#                             'desktop", including embodied and embedded '
#                             'interaction, ubiquitous computing, affective '
#                             'computing, tangible interaction, gesture-based '
#                             'interaction, natural user interfaces, and '
#                             'virtual/augmented reality. Moreover, there will '
#                             'be an emphasis on understanding the intimate, '
#                             'bi-directional, and co-evolving relationship '
#                             'between human minds and bodies on the one hand, '
#                             'and interactive technologies on the other, '
#                             'highlighting the ways in which technology can '
#                             'support and leverage, but also constrain and '
#                             'limit, human thought and experience.'},
#                   {'language': 'en-GB',
#                    'value': '\n'
#                             'Cognitive engineering is a multidisciplinary '
#                             'endeavour concerned with the analysis, design, '
#                             'and evaluation of complex systems of people and '
#                             'technology. It combines knowledge and experience '
#                             'from cognitive science, human factors, '
#                             'human-computer interaction design, and systems '
#                             'engineering. The traditional focus of cognitive '
#                             'engineering has been on understanding the '
#                             'cognitive demands imposed by complex work '
#                             'environments, and designing systems that will '
#                             'help create an optimal sociotechnical ecosystem. '
#                             'However, as ICT is increasingly moving beyond the '
#                             'workplace, into private and public realms, and '
#                             'ICT systems are embedded into everyday objects '
#                             'and environments, the scope of the course will '
#                             'include new application domains (e.g., in home, '
#                             'healthcare, or automotive contexts), new '
#                             'interaction styles and paradigms (e.g., '
#                             'ubiquitous computing, gesture-based computing, '
#                             'affective computing) as well new theoretical '
#                             'frameworks that are required to understand '
#                             "humans' co-adaptive relationship with technology "
#                             '(e.g., embodied cognition, extended mind, '
#                             'distributed cognition).  \n'
#                             '\n'
#                             'In this course, you will be introduced to the '
#                             'basic principles of cognitive systems engineering '
#                             'and obtain an appreciation of the main trends and '
#                             'developments in interface design "beyond the '
#                             'desktop", including embodied and embedded '
#                             'interaction, ubiquitous computing, affective '
#                             'computing, tangible interaction, gesture-based '
#                             'interaction, natural user interfaces, and '
#                             'virtual/augmented reality. Moreover, there will '
#                             'be an emphasis on understanding the intimate, '
#                             'bi-directional, and co-evolving relationship '
#                             'between human minds and bodies on the one hand, '
#                             'and interactive technologies on the other, '
#                             'highlighting the ways in which technology can '
#                             'support and leverage, but also constrain and '
#                             'limit, human thought and experience.'}],
#   'duration': '',
#   'enrollment': [],
#   'ext': {},
#   'fieldsOfStudy': '',
#   'firstStartDate': '',
#   'learningOutcomes': [[{'language': 'nl-NL',
#                          'value': 'After following this course, students '
#                                   'should be able to:\n'
#                                   '- have an appreciation of the main trends '
#                                   'and developments in cognitive engineering, '
#                                   'and interface design “beyond the desktop”, '
#                                   'including its application in relevant '
#                                   'contexts (e.g., work, home, healthcare, '
#                                   'automotive)\n'
#                                   '- explain key concepts and theories that '
#                                   'relate to human-computer interaction, '
#                                   'including recent interface concepts “beyond '
#                                   'the desktop”, including ambient '
#                                   'intelligence, ubiquitous computing, '
#                                   'affective computing, tangible interaction, '
#                                   'gesture-based interaction, natural user '
#                                   'interfaces, virtual and augmented reality;\n'
#                                   '- discuss effects of media technology on '
#                                   'user experience, engagement, affect, '
#                                   'cognition, and memory, and the ways in '
#                                   'which technology can support and leverage, '
#                                   'but also constrain and limit, human thought '
#                                   'and experience;\n'
#                                   '- discuss theoretical perspectives that '
#                                   'highlight the intimate, bi-directional, and '
#                                   'co-evolving relationship between human '
#                                   'minds and interactive technologies, '
#                                   'including embodied, embedded and extended '
#                                   'views of human cognition;\n'
#                                   '- critically assess the main psychological '
#                                   'and ethical issues related to embodied and '
#                                   'embedded computing, including issues of '
#                                   'individual control, privacy, and '
#                                   'überveillance.\n'
#                                   '\n'},
#                         {'language': 'en-GB',
#                          'value': 'After following this course, students '
#                                   'should be able to:\n'
#                                   '- have an appreciation of the main trends '
#                                   'and developments in cognitive engineering, '
#                                   'and interface design “beyond the desktop”, '
#                                   'including its application in relevant '
#                                   'contexts (e.g., work, home, healthcare, '
#                                   'automotive)\n'
#                                   '- explain key concepts and theories that '
#                                   'relate to human-computer interaction, '
#                                   'including recent interface concepts “beyond '
#                                   'the desktop”, including ambient '
#                                   'intelligence, ubiquitous computing, '
#                                   'affective computing, tangible interaction, '
#                                   'gesture-based interaction, natural user '
#                                   'interfaces, virtual and augmented reality;\n'
#                                   '- discuss effects of media technology on '
#                                   'user experience, engagement, affect, '
#                                   'cognition, and memory, and the ways in '
#                                   'which technology can support and leverage, '
#                                   'but also constrain and limit, human thought '
#                                   'and experience;\n'
#                                   '- discuss theoretical perspectives that '
#                                   'highlight the intimate, bi-directional, and '
#                                   'co-evolving relationship between human '
#                                   'minds and interactive technologies, '
#                                   'including embodied, embedded and extended '
#                                   'views of human cognition;\n'
#                                   '- critically assess the main psychological '
#                                   'and ethical issues related to embodied and '
#                                   'embedded computing, including issues of '
#                                   'individual control, privacy, and '
#                                   'überveillance.\n'
#                                   '\n'}]],
#   'level': 'master',
#   'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642486&taal=nl',
#   'modeOfDelivery': [],
#   'name': [{'language': 'nl-NL', 'value': 'Advanced cognitive engineering'},
#            {'language': 'en-GB', 'value': 'Advanced cognitive engineering'}],
#   'otherCodes': [],
#   'primaryCode': {'code': 'c2af7f53-6cf6-4cd2-870d-b91d6ba001e0',
#                   'codeType': 'uuid'},
#   'qualificationRequirements': [],
#   'resources': [' Clive Thompson (2013). Smarter than you think. How '
#                 'technology is changing our minds for the better. London: '
#                 'William Collins.',
#                 ' Capita selecta'],
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#   'teachingLanguage': 'eng',
#   'validFrom': '',
#   'validTo': ''},
#  {'abbreviation': '0HM120',
#   'addresses': [],
#   'admissionRequirements': [{'language': 'nl-NL',
#                              'value': 'Je moet voldoen aan één van de '
#                                       'onderstaande verzamelingen met eisen\n'
#                                       '- Verzameling 1\n'
#                                       '- Bachelor of Science (BSc) afgerond\n'
#                                       '- Verzameling 2\n'
#                                       '- Schakelprogramma afgerond'},
#                             {'language': 'en-GB',
#                              'value': 'You must meet one of the following '
#                                       'collections of requirements\n'
#                                       '- Collection 1\n'
#                                       '- Completed Final examination Bsc '
#                                       'program\n'
#                                       '- Collection 2\n'
#                                       '- Completed Pre-Master'}],
#   'assessment': [],
#   'consumers': [{'alliances': [{'name': 'EWUU',
#                                 'selection': False,
#                                 'theme': '',
#                                 'type': 'broadening',
#                                 'visibleForOwnStudents': False}],
#                  'consumerKey': 'eduxchange'}],
#   'courseId': '06167ec8-cf12-41e3-b781-a4665b039944',
#   'description': [{'language': 'nl-NL',
#                    'value': '\n'
#                             "Solid execution of one's professional duties as "
#                             'an HTI engineer requires in-depth knowledge of '
#                             'and experience with the statistical processing of '
#                             'data. Besides assisting the student in mastering '
#                             'several more advanced statistical techniques '
#                             '(path models, contrast analysis), the advanced '
#                             'data analysis course allows students to '
#                             'consolidate their bachelor level statistical '
#                             'knowledge by developing a critical attitude '
#                             'toward data analysis and gaining experience with '
#                             'dealing with statistical problems that are '
#                             'typically relevant to the HTI domain. Taken '
#                             'together, the course provides students with '
#                             'sufficient statistical and data analytical '
#                             "expertise to analyze and interpret not only one's "
#                             'own research data (e.g., research project or '
#                             'graduation project), but also data collected and '
#                             '/or analyzed by other researchers in their '
#                             'domain.  \n'
#                             '\n'
#                             '\n'
#                             'Throughout the course the following topics will '
#                             'be addressed:\n'
#                             '- Data analysis as a way of asking theoretically '
#                             'guided statistical questions\n'
#                             '- The ins and outs of hypothesis testing, power, '
#                             'replication, and meta-analysis\n'
#                             '- Working with SPSS and STATA\n'
#                             '- Path analysis using regression (e.g., '
#                             'mediation)\n'
#                             '- Analysis of covariance and its various uses\n'
#                             '- Contrast analysis\n'
#                             '\n'},
#                   {'language': 'en-GB',
#                    'value': '\n'
#                             "Solid execution of one's professional duties as "
#                             'an HTI engineer requires in-depth knowledge of '
#                             'and experience with the statistical processing of '
#                             'data. Besides assisting the student in mastering '
#                             'several more advanced statistical techniques '
#                             '(path models, contrast analysis), the advanced '
#                             'data analysis course allows students to '
#                             'consolidate their bachelor level statistical '
#                             'knowledge by developing a critical attitude '
#                             'toward data analysis and gaining experience with '
#                             'dealing with statistical problems that are '
#                             'typically relevant to the HTI domain. Taken '
#                             'together, the course provides students with '
#                             'sufficient statistical and data analytical '
#                             "expertise to analyze and interpret not only one's "
#                             'own research data (e.g., research project or '
#                             'graduation project), but also data collected and '
#                             '/or analyzed by other researchers in their '
#                             'domain.  \n'
#                             '\n'
#                             '\n'
#                             'Throughout the course the following topics will '
#                             'be addressed:\n'
#                             '- Data analysis as a way of asking theoretically '
#                             'guided statistical questions\n'
#                             '- The ins and outs of hypothesis testing, power, '
#                             'replication, and meta-analysis\n'
#                             '- Working with SPSS and STATA\n'
#                             '- Path analysis using regression (e.g., '
#                             'mediation)\n'
#                             '- Analysis of covariance and its various uses\n'
#                             '- Contrast analysis\n'
#                             '\n'}],
#   'duration': '',
#   'enrollment': [],
#   'ext': {},
#   'fieldsOfStudy': '',
#   'firstStartDate': '',
#   'learningOutcomes': [[{'language': 'nl-NL',
#                          'value': 'After successful completion of the course, '
#                                   'the student\n'
#                                   '- can explain the fundamentals of the '
#                                   'theories behind the targeted statistical '
#                                   'techniques\n'
#                                   '- has acquired the skills necessary for '
#                                   'applying these techniques, on his or her '
#                                   'own, to problems relevant for the HTI, and '
#                                   'to appropriately report on the results of '
#                                   'statistical analyses\n'
#                                   '- has learned to read and master primary '
#                                   'theoretical literature in the domains of '
#                                   'data-analysis and statistics.\n'
#                                   '- can reflect critically on his or her own '
#                                   'data analysis skills and activities and on '
#                                   'that of others; being able, for example, to '
#                                   'explain what constitutes proper data '
#                                   'analysis (e.g., with respect to sample '
#                                   'size, robustness, and the selection of '
#                                   'appropriate techniques).\n'
#                                   '\n'},
#                         {'language': 'en-GB',
#                          'value': 'After successful completion of the course, '
#                                   'the student\n'
#                                   '- can explain the fundamentals of the '
#                                   'theories behind the targeted statistical '
#                                   'techniques\n'
#                                   '- has acquired the skills necessary for '
#                                   'applying these techniques, on his or her '
#                                   'own, to problems relevant for the HTI, and '
#                                   'to appropriately report on the results of '
#                                   'statistical analyses\n'
#                                   '- has learned to read and master primary '
#                                   'theoretical literature in the domains of '
#                                   'data-analysis and statistics.\n'
#                                   '- can reflect critically on his or her own '
#                                   'data analysis skills and activities and on '
#                                   'that of others; being able, for example, to '
#                                   'explain what constitutes proper data '
#                                   'analysis (e.g., with respect to sample '
#                                   'size, robustness, and the selection of '
#                                   'appropriate techniques).\n'
#                                   '\n'}]],
#   'level': 'master',
#   'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642483&taal=nl',
#   'modeOfDelivery': [],
#   'name': [{'language': 'nl-NL', 'value': 'Advanced data analysis'},
#            {'language': 'en-GB', 'value': 'Advanced data analysis'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '06167ec8-cf12-41e3-b781-a4665b039944',
#                   'codeType': 'uuid'},
#   'qualificationRequirements': [],
#   'resources': [' Selected book chapters and articles (mandatory and '
#                 'recommended readings)',
#                 'Gpower http://www.gpower.hhu.de (Heinrich Heine Universität '
#                 'Düsseldorf)',
#                 'SPSS 23 http://www-01.ibm.com/software/analytics/spss/ (IBM)',
#                 'Stata http://www.dpc-software.nl/ (Stata Corp LP)'],
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#   'teachingLanguage': 'eng',
#   'validFrom': '',
#   'validTo': ''},
#  {'abbreviation': '0HM140',
#   'addresses': [],
#   'admissionRequirements': [{'language': 'nl-NL',
#                              'value': 'Je moet voldoen aan één van de '
#                                       'onderstaande verzamelingen met eisen\n'
#                                       '- Verzameling 1\n'
#                                       '- Bachelor of Science (BSc) afgerond\n'
#                                       '- Verzameling 2\n'
#                                       '- Schakelprogramma afgerond'},
#                             {'language': 'en-GB',
#                              'value': 'You must meet one of the following '
#                                       'collections of requirements\n'
#                                       '- Collection 1\n'
#                                       '- Completed Final examination Bsc '
#                                       'program\n'
#                                       '- Collection 2\n'
#                                       '- Completed Pre-Master'}],
#   'assessment': [],
#   'consumers': [{'alliances': [{'name': 'EWUU',
#                                 'selection': False,
#                                 'theme': '',
#                                 'type': 'broadening',
#                                 'visibleForOwnStudents': False}],
#                  'consumerKey': 'eduxchange'}],
#   'courseId': 'b67b1c22-290c-48b5-936f-9d06a22948e5',
#   'description': [{'language': 'nl-NL',
#                    'value': 'This course covers advanced knowledge about '
#                             'perceptual processes in interaction with modern '
#                             'technologies. The course will discuss '
#                             'quantitative modeling and present basic human '
#                             'recognition models and models for information '
#                             'representation, as well as methods to develop and '
#                             'estimate their parameters.  \n'
#                             '  \n'
#                             'Perception may seem trivial since people usually '
#                             'assume that we see, feel and experience the world '
#                             'just as it is. However, extraordinarily '
#                             'fascinating and complex processes occupy more '
#                             'than half of the brain to accomplish this '
#                             'seemingly effortless feat. When measuring '
#                             'perception quantitatively, it turns out that '
#                             'perception does not at all result in a faithful '
#                             'representation of physical reality. All sorts of '
#                             'systematic deviations occur. Nonetheless, this '
#                             'does not substantially affect us in daily life. '
#                             'In extreme circumstances, however, like moving at '
#                             'high speeds, perceptual errors are often a cause '
#                             'for human failure.  \n'
#                             '  \n'
#                             'A good understanding of human perception is '
#                             'essential for many areas of research. For '
#                             'instance:\n'
#                             '- It provides insights into how information '
#                             'should be presented to human observers.\n'
#                             '- It can be used to optimize what people see, how '
#                             'they perform and how they feel.\n'
#                             '- It can be used to understand underlying causes '
#                             'of human failure.\n'
#                             '- It provides insights on how to optimize the '
#                             'design of current and new technological '
#                             'applications, such as displays, artificial '
#                             'agents, computer vision, medical imaging, etc.\n'
#                             '\n'
#                             '  \n'
#                             'The course expands on base knowledge from the '
#                             'bachelor course 0HV20 Perception and Motor '
#                             'control. While having taken this course is an '
#                             'advantage, all necessary concepts will be briefly '
#                             'introduced again.  Several specific topics of '
#                             'human perception are discussed in depth. These '
#                             'topics are related to the research areas within '
#                             'the HTI group, and, thus, they provide concrete '
#                             'examples of topics for the HTI master thesis. The '
#                             'topics include:\n'
#                             '- Signal detection theory & Psychophysics\n'
#                             '- Bayesian models of perception\n'
#                             '- Decision making in the brain\n'
#                             '- Saccadic eye movements\n'
#                             '- Visual perception\n'
#                             '- Haptic perception\n'
#                             '- Multisensory perception\n'
#                             '\n'},
#                   {'language': 'en-GB',
#                    'value': 'This course covers advanced knowledge about '
#                             'perceptual processes in interaction with modern '
#                             'technologies. The course will discuss '
#                             'quantitative modeling and present basic human '
#                             'recognition models and models for information '
#                             'representation, as well as methods to develop and '
#                             'estimate their parameters.  \n'
#                             '  \n'
#                             'Perception may seem trivial since people usually '
#                             'assume that we see, feel and experience the world '
#                             'just as it is. However, extraordinarily '
#                             'fascinating and complex processes occupy more '
#                             'than half of the brain to accomplish this '
#                             'seemingly effortless feat. When measuring '
#                             'perception quantitatively, it turns out that '
#                             'perception does not at all result in a faithful '
#                             'representation of physical reality. All sorts of '
#                             'systematic deviations occur. Nonetheless, this '
#                             'does not substantially affect us in daily life. '
#                             'In extreme circumstances, however, like moving at '
#                             'high speeds, perceptual errors are often a cause '
#                             'for human failure.  \n'
#                             '  \n'
#                             'A good understanding of human perception is '
#                             'essential for many areas of research. For '
#                             'instance:\n'
#                             '- It provides insights into how information '
#                             'should be presented to human observers.\n'
#                             '- It can be used to optimize what people see, how '
#                             'they perform and how they feel.\n'
#                             '- It can be used to understand underlying causes '
#                             'of human failure.\n'
#                             '- It provides insights on how to optimize the '
#                             'design of current and new technological '
#                             'applications, such as displays, artificial '
#                             'agents, computer vision, medical imaging, etc.\n'
#                             '\n'
#                             '  \n'
#                             'The course expands on base knowledge from the '
#                             'bachelor course 0HV20 Perception and Motor '
#                             'control. While having taken this course is an '
#                             'advantage, all necessary concepts will be briefly '
#                             'introduced again. Several specific topics of '
#                             'human perception are discussed in depth. These '
#                             'topics are related to the research areas within '
#                             'the HTI group, and, thus, they provide concrete '
#                             'examples of topics for the HTI master thesis. The '
#                             'topics include:\n'
#                             '- Signal detection theory & Psychophysics\n'
#                             '- Bayesian models of perception\n'
#                             '- Decision making in the brain\n'
#                             '- Saccadic eye movements\n'
#                             '- Visual perception\n'
#                             '- Haptic perception\n'
#                             '- Multisensory perception\n'
#                             '\n'}],
#   'duration': '',
#   'enrollment': [],
#   'ext': {},
#   'fieldsOfStudy': '',
#   'firstStartDate': '',
#   'learningOutcomes': [[{'language': 'nl-NL',
#                          'value': '\n'
#                                   'After this course, students are able to:\n'
#                                   '- develop and evaluate models of human '
#                                   'perception,\n'
#                                   '- describe the relation between human '
#                                   'perception and methods of signal coding for '
#                                   'perceptual information,\n'
#                                   '- evaluate the perceptual requirements '
#                                   'applicable in a user-centered design '
#                                   'approach to optimize current and novel '
#                                   'technological developments in multi-media '
#                                   'applications,\n'
#                                   '- describe the possibilities and limits of '
#                                   'human perception in realistic situations,\n'
#                                   '- critically read scientific papers not '
#                                   'directly written for educational purposes,\n'
#                                   '- apply the theoretical topics of the '
#                                   'lectures in a practical setting through the '
#                                   'practical assignments.\n'
#                                   '\n'},
#                         {'language': 'en-GB',
#                          'value': '\n'
#                                   'After this course, students are able to:\n'
#                                   '- develop and evaluate models of human '
#                                   'perception,\n'
#                                   '- describe the relation between human '
#                                   'perception and methods of signal coding for '
#                                   'perceptual information,\n'
#                                   '- evaluate the perceptual requirements '
#                                   'applicable in a user-centered design '
#                                   'approach to optimize current and novel '
#                                   'technological developments in multi-media '
#                                   'applications,\n'
#                                   '- describe the possibilities and limits of '
#                                   'human perception in realistic situations,\n'
#                                   '- critically read scientific papers not '
#                                   'directly written for educational purposes,\n'
#                                   '- apply the theoretical topics of the '
#                                   'lectures in a practical setting through the '
#                                   'practical assignments.\n'
#                                   '\n'}]],
#   'level': 'master',
#   'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642485&taal=nl',
#   'modeOfDelivery': [],
#   'name': [{'language': 'nl-NL', 'value': 'Advanced perception'},
#            {'language': 'en-GB', 'value': 'Advanced perception'}],
#   'otherCodes': [],
#   'primaryCode': {'code': 'b67b1c22-290c-48b5-936f-9d06a22948e5',
#                   'codeType': 'uuid'},
#   'qualificationRequirements': [],
#   'resources': [' The study material consists of research papers and book '
#                 'chapters, which will be provided in advance for each lecture '
#                 'separately. It is recommended to have read the distributed '
#                 'material before the lecture.'],
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#   'teachingLanguage': 'eng',
#   'validFrom': '',
#   'validTo': ''},
#  {'abbreviation': '6EMA06',
#   'addresses': [],
#   'admissionRequirements': [{'language': 'nl-NL',
#                              'value': 'Knowledge acquired  on e.g., knowledge '
#                                       'of unit operations, ability to perform '
#                                       'design calculations for equilibrium '
#                                       'based separation technologies, ability '
#                                       'to perform design calculations for '
#                                       'mechanical, rate based and reactive '
#                                       'separation technologies, product design '
#                                       '& process management.'},
#                             {'language': 'en-GB',
#                              'value': 'Knowledge acquired  on e.g., knowledge '
#                                       'of unit operations, ability to perform '
#                                       'design calculations for equilibrium '
#                                       'based separation technologies, ability '
#                                       'to perform design calculations for '
#                                       'mechanical, rate based and reactive '
#                                       'separation technologies, product design '
#                                       '& process management.'}],
#   'assessment': [],
#   'consumers': [{'alliances': [{'name': 'EWUU',
#                                 'selection': False,
#                                 'theme': '',
#                                 'type': 'broadening',
#                                 'visibleForOwnStudents': False}],
#                  'consumerKey': 'eduxchange'}],
#   'courseId': 'afc388a5-345f-494a-b40c-5eae74906204',
#   'description': [{'language': 'nl-NL',
#                    'value': 'In this course we will design a substantial part '
#                             'of a process in fair detail, starting from a '
#                             'laboratory recipe. This design will include '
#                             'various types of reactors, separators and heat '
#                             'exchangers. Various models required for this '
#                             'design with respect to thermodynamic properties, '
#                             'heat and mass transfer, and reaction kinetics '
#                             'will have to be used to come to a proper '
#                             'scale-up. As a modeling tool, AspenPlus will be '
#                             'used, extended with a costing program. Apart from '
#                             'optimizing the process in its major equipment '
#                             'items, special attention will be paid to the '
#                             'selection of operations which require less energy '
#                             'and yield less waste. Additionally, the choices '
#                             'to be made will be placed in an economic '
#                             'perspective, for which NPV and IRR analysis will '
#                             'be used.  \n'
#                             '  \n'
#                             '**Extra information about the assessment**   \n'
#                             '  \n'
#                             '•Assignment(s)in groups of (maximum) 4 '
#                             'students  \n'
#                             '• Written reports during the course that will be '
#                             'condensed in larger final part of the case  \n'
# ...
#                             'design choices could both be understood and be '
#                             'justified, conceptualized and reasoned about, '
#                             'using philosophical ideas. Any designer, to come '
#                             'to a refined view of what might be a good design, '
#                             'needs to develop their frame of reference and be '
#                             'able to justify their choices sensibly. For this '
#                             'purpose the essay/position paper has proved '
#                             'itself a wonderful medium. It allows us to '
#                             'document and compare the experiences and ideas of '
#                             'others and to nuance these relative to a specific '
#                             'situation or problem that is our own specific '
#                             'concern. It is, as such crucial that a designer '
#                             'learns to formulate their attitude to a design '
#                             'task on the basis of a careful weighing of '
#                             'alternative views, opinions and facts. This is '
#                             'why this course is important to you.  \n'
#                             '  \n'
#                             'The course is built up of five elements:  \n'
#                             '\n'
#                             '\n'
#                             '1. A course of lectures in which various themes '
#                             'are introduced and used for\n'
#                             '2. Discussion\n'
#                             '3. The close reading and group analysis of '
#                             'relevant philosophical literature\n'
#                             '4. The writing and critiquing of an '
#                             'essay/position paper in a group\n'
#                             '5. The writing of a short essay in exam '
#                             'conditions\n'
#                             '\n'
#                             'As such the course requires certain kinds of '
#                             'knowledge and skill, which we assume you already '
#                             'have:\n'
#                             '- The ability to participate actively in '
#                             'discussions about the relationship between '
#                             'design, building and thought, through the study '
#                             'of specific cases.\n'
#                             '- The ability to find relevant literature, read '
#                             'it critically, to summarise its core points and '
#                             'to find the arguments supporting its position. '
#                             '(Help in finding literature can be had from the '
#                             'library staff)\n'
#                             '- The ability to describe architecture and '
#                             'explain concepts and subject both to critical '
#                             'reflection. (This skill will of course be '
#                             'practised during this course but it is hoped you '
#                             'have had a little more experience in such '
#                             'things)\n'
#                             '- The ability to formulate and defend a position '
#                             'relative to the subject chosen and to formulate '
#                             'those arguments in such a way that together they '
#                             'become a coherent whole, leading to a conclusion '
#                             'in which the main arguments are summarised and '
#                             'the practical consequences of a position are '
#                             'explored.\n'
#                             '\n'},
#                   {'language': 'en-GB',
#                    'value': 'Design facilitates activity, modifies climate and '
#                             'thinks about the making. In all this it delights '
#                             'the user in whichever way he or she uses the '
#                             'building. The big challenge of design is its '
#                             'freedom: anything is possible, however a lot of '
#                             'what is possible is not very sensible. This means '
#                             'that every design decision has to be justified in '
#                             'some way. We need to know why we want to do this, '
#                             'rather than that. Design is a social institution; '
#                             'it concerns itself with applying the requisite '
#                             'technology and know-how to the production of a '
#                             'social space that answers our aspirations. Each '
#                             'design decision needs to be justified against an '
#                             'idea of what is desired and each desire must in '
#                             'turn be justified against experience and hope, '
#                             'preferably in the form of compelling (scientific) '
#                             'evidence. The course will draw from different '
#                             'subfields of philosophy (epistemology, '
#                             'aesthetics, philosophy of technology, ethics, '
#                             'political philosophy etc.) to investigate how '
#                             'design choices could both be understood and be '
#                             'justified, conceptualized and reasoned about, '
#                             'using philosophical ideas. Any designer, to come '
#                             'to a refined view of what might be a good design, '
#                             'needs to develop their frame of reference and be '
#                             'able to justify their choices sensibly. For this '
#                             'purpose the essay/position paper has proved '
#                             'itself a wonderful medium. It allows us to '
#                             'document and compare the experiences and ideas of '
#                             'others and to nuance these relative to a specific '
#                             'situation or problem that is our own specific '
#                             'concern. It is, as such crucial that a designer '
#                             'learns to formulate their attitude to a design '
#                             'task on the basis of a careful weighing of '
#                             'alternative views, opinions and facts. This is '
#                             'why this course is important to you.  \n'
#                             '  \n'
#                             'The course is built up of five elements:  \n'
#                             '\n'
#                             '\n'
#                             '1. A course of lectures in which various themes '
#                             'are introduced and used for\n'
#                             '2. Discussion\n'
#                             '3. The close reading and group analysis of '
#                             'relevant philosophical literature\n'
#                             '4. The writing and critiquing of an '
#                             'essay/position paper in a group\n'
#                             '5. The writing of a short essay in exam '
#                             'conditions\n'
#                             '\n'
#                             'As such the course requires certain kinds of '
#                             'knowledge and skill, which we assume you already '
#                             'have:\n'
#                             '- The ability to participate actively in '
#                             'discussions about the relationship between '
#                             'design, building and thought, through the study '
#                             'of specific cases.\n'
#                             '- The ability to find relevant literature, read '
#                             'it critically, to summarise its core points and '
#                             'to find the arguments supporting its position. '
#                             '(Help in finding literature can be had from the '
#                             'library staff)\n'
#                             '- The ability to describe architecture and '
#                             'explain concepts and subject both to critical '
#                             'reflection. (This skill will of course be '
#                             'practised during this course but it is hoped you '
#                             'have had a little more experience in such '
#                             'things)\n'
#                             '- The ability to formulate and defend a position '
#                             'relative to the subject chosen and to formulate '
#                             'those arguments in such a way that together they '
#                             'become a coherent whole, leading to a conclusion '
#                             'in which the main arguments are summarised and '
#                             'the practical consequences of a position are '
#                             'explored.\n'
#                             '\n'}],
#   'duration': '',
#   'enrollment': [],
#   'ext': {},
#   'fieldsOfStudy': '',
#   'firstStartDate': '',
#   'learningOutcomes': [[{'language': 'nl-NL',
#                          'value': '**Educational objectives**   \n'
#                                   'Through the concrete examination and '
#                                   'critique of specific texts, buildings, '
#                                   'designs and urban agglomerations from a '
#                                   'specific point of view, you will, at the '
#                                   'end of the course, be in a position to '
#                                   'place your own efforts in design and design '
#                                   'thinking within an increasingly refined and '
#                                   'well-practised frame of reference, helping '
#                                   'you to make considered design decisions '
#                                   'within social space and thereby undertake '
#                                   'and undergo the odyssey of the design '
#                                   'process with greater awareness and '
#                                   'therefore with greater freedom. The purpose '
#                                   'of this course is to give you the '
#                                   'opportunity to learn to:\n'
#                                   '- Write an essay/position paper exploring '
#                                   'your own theoretical position relative to a '
#                                   'chosen topic.\n'
#                                   '- Explain your choice for this topic in '
#                                   'relation to your own ambitions as a '
#                                   'practitioner\n'
#                                   '- Formulate a specific research question '
#                                   'which can be investigated using literature '
#                                   'as well as concrete examples from the built '
#                                   'environment in order to form a thoroughly '
#                                   'argued attitude to the design process.\n'
#                                   '- Contextualise the topic within the '
#                                   'current debate about the built '
#                                   'environment.\n'
#                                   '- Summarise the positions of (two) other '
#                                   'authors on this topic.\n'
#                                   '- Nuance their theoretical positions and '
#                                   'take up a position within the debate.\n'
#                                   '- Define and underpin their own position '
#                                   'with arguments and examples.\n'
#                                   '- Perform research according to the '
#                                   'accepted criteria of scholarship.\n'
#                                   '\n'},
#                         {'language': 'en-GB',
#                          'value': '**Educational objectives**   \n'
#                                   'Through the concrete examination and '
#                                   'critique of specific texts, buildings, '
#                                   'designs and urban agglomerations from a '
#                                   'specific point of view, you will, at the '
#                                   'end of the course, be in a position to '
#                                   'place your own efforts in design and design '
#                                   'thinking within an increasingly refined and '
#                                   'well-practised frame of reference, helping '
#                                   'you to make considered design decisions '
#                                   'within social space and thereby undertake '
#                                   'and undergo the odyssey of the design '
#                                   'process with greater awareness and '
#                                   'therefore with greater freedom. The purpose '
#                                   'of this course is to give you the '
#                                   'opportunity to learn to:\n'
#                                   '- Write an essay/position paper exploring '
#                                   'your own theoretical position relative to a '
#                                   'chosen topic.\n'
#                                   '- Explain your choice for this topic in '
#                                   'relation to your own ambitions as a '
#                                   'practitioner\n'
#                                   '- Formulate a specific research question '
#                                   'which can be investigated using literature '
#                                   'as well as concrete examples from the built '
#                                   'environment in order to form a thoroughly '
#                                   'argued attitude to the design process.\n'
#                                   '- Contextualise the topic within the '
#                                   'current debate about the built '
#                                   'environment.\n'
#                                   '- Summarise the positions of (two) other '
#                                   'authors on this topic.\n'
#                                   '- Nuance their theoretical positions and '
#                                   'take up a position within the debate.\n'
#                                   '- Define and underpin their own position '
#                                   'with arguments and examples.\n'
#                                   '- Perform research according to the '
#                                   'accepted criteria of scholarship.\n'
#                                   '\n'}]],
#   'level': 'master',
#   'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1641846&taal=nl',
#   'modeOfDelivery': [],
#   'name': [{'language': 'nl-NL', 'value': 'Architecture and philosophy'},
#            {'language': 'en-GB', 'value': 'Architecture and philosophy'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '1448ba57-e455-4ff9-88f8-00d936280a33',
#                   'codeType': 'uuid'},
#   'qualificationRequirements': [],
#   'resources': [' The literature we shall be studying varies with every year. '
#                 'You will be given the titels on Canvas.',
#                 ' For a list of further recommended literature, please see '
#                 'Canvas.'],
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#   'teachingLanguage': 'eng',
#   'validFrom': '',
#   'validTo': ''}]

# %%
print("GET /courses/{courseId}/offerings")

headers = {
    "api-key": API_KEY
}

params = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/courses"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)
data = response.json()

if data.get('items') and len(data['items']) > 0:
    course_id = data['items'][0]['courseId']
    print(f"Testing with course ID: {course_id}")
    pprint(data['items'][0])
    
    
else:
    print("No courses available")
# Out:
# GET /courses/{courseId}/offerings
# Testing with course ID: 2b0e22fb-3c19-48a0-a48c-046c7211e9e9
# {'abbreviation': '0HM130',
#  'addresses': [],
#  'admissionRequirements': [{'language': 'nl-NL',
#                             'value': 'Je moet voldoen aan één van de '
#                                      'onderstaande verzamelingen met eisen\n'
#                                      '- Verzameling 1\n'
#                                      '- Bachelor of Science (BSc) afgerond\n'
#                                      '- Verzameling 2\n'
#                                      '- Schakelprogramma afgerond'},
#                            {'language': 'en-GB',
#                             'value': 'You must meet one of the following '
#                                      'collections of requirements\n'
#                                      '- Collection 1\n'
#                                      '- Completed Final examination Bsc '
#                                      'program\n'
#                                      '- Collection 2\n'
#                                      '- Completed Pre-Master'}],
#  'assessment': [],
#  'consumers': [{'alliances': [{'name': 'EWUU',
#                                'selection': False,
#                                'theme': '',
#                                'type': 'broadening',
#                                'visibleForOwnStudents': False}],
#                 'consumerKey': 'eduxchange'}],
#  'courseId': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#  'description': [{'language': 'nl-NL',
#                   'value': 'The course consists of 10 lectures.   \n'
#                            'The lectures cover core topics in cognition '
#                            '(representations, attention, memory, language, '
#                            'categorization, creativity and AI, and '
#                            'similarity). These lecture will be accompanied by '
#                            'weekly assignments where students experience basic '
#                            'experimental paradigms in cognitive psychology, '
#                            'such as the Simon Effect, Working Memory Tasks, '
#                            'and Similarity experiments. Students will perform '
#                            'these experiments, reflect upon their underlying '
#                            'mechanisms and link them to theories in the '
#                            'reading material, and translate the relevance of '
#                            'these mechanisms to facets of human-technology '
#                            'interaction. Lectures are also accompanied by '
#                            'applied assignments providing advice for a '
#                            '(hypothetical) behavioral insight team that used '
#                            'knowledge from cognitive psychology to address a '
#                            'societal problem.'},
#                  {'language': 'en-GB',
#                   'value': 'The course consists of 10 lectures.   \n'
#                            'The lectures cover core topics in cognition '
#                            '(representations, attention, memory, language, '
#                            'categorization, creativity and AI, and '
#                            'similarity). These lecture will be accompanied by '
#                            'weekly assignments where students experience basic '
#                            'experimental paradigms in cognitive psychology, '
#                            'such as the Simon Effect, Working Memory Tasks, '
#                            'and Similarity experiments. Students will perform '
#                            'these experiments, reflect upon their underlying '
#                            'mechanisms and link them to theories in the '
#                            'reading material, and translate the relevance of '
#                            'these mechanisms to facets of human-technology '
#                            'interaction. Lectures are also accompanied by '
#                            'applied assignments providing advice for a '
#                            '(hypothetical) behavioral insight team that used '
#                            'knowledge from cognitive psychology to address a '
#                            'societal problem.'}],
#  'duration': '',
#  'enrollment': [],
#  'ext': {},
#  'fieldsOfStudy': '',
#  'firstStartDate': '',
#  'learningOutcomes': [[{'language': 'nl-NL',
#                         'value': '\n'
#                                  'The goal of the course is to gain a further '
#                                  'understanding of the basic research '
#                                  'questions and methodologies of cognitive '
#                                  'science.  \n'
#                                  '\n'
#                                  '\n'
#                                  'After the course, students will be able to:\n'
#                                  '- interpret empirical findings in cognitive '
#                                  'science in light of theoretical ideas,\n'
#                                  '- interpret classical findings and paradigms '
#                                  'in cognitive science,\n'
#                                  '- explain empirical findings from different '
#                                  'theoretical perspectives,\n'
#                                  '- apply scientific knowledge in a technical '
#                                  'domain and for government policy,\n'
#                                  '- critically evaluate ongoing scientific '
#                                  'research.\n'
#                                  '\n'},
#                        {'language': 'en-GB',
#                         'value': '\n'
#                                  'The goal of the course is to gain a further '
#                                  'understanding of the basic research '
#                                  'questions and methodologies of cognitive '
#                                  'science.  \n'
#                                  '\n'
#                                  '\n'
#                                  'After the course, students will be able to:\n'
#                                  '- interpret empirical findings in cognitive '
#                                  'science in light of theoretical ideas,\n'
#                                  '- interpret classical findings and paradigms '
#                                  'in cognitive science,\n'
#                                  '- explain empirical findings from different '
#                                  'theoretical perspectives,\n'
#                                  '- apply scientific knowledge in a technical '
#                                  'domain and for government policy,\n'
#                                  '- critically evaluate ongoing scientific '
#                                  'research.\n'
#                                  '\n'}]],
#  'level': 'master',
#  'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642484&taal=nl',
#  'modeOfDelivery': [],
#  'name': [{'language': 'nl-NL', 'value': 'Advanced cognition'},
#           {'language': 'en-GB', 'value': 'Advanced cognition'}],
#  'otherCodes': [],
#  'primaryCode': {'code': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#                  'codeType': 'uuid'},
#  'qualificationRequirements': [],
#  'resources': [' No book. Articles and chapters are provided by the lecturer.'],
#  'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#  'teachingLanguage': 'eng',
#  'validFrom': '',
#  'validTo': ''}

# %%
print("GET /courses/{courseId}/components")

headers = {
    "api-key": API_KEY
}

params = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/courses"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)
data = response.json()

if data.get("items") and len(data["items"]) > 0:
    course_id = data["items"][0]["courseId"]
    print(f"Testing with course ID: {course_id}")
    pprint(data["items"][0])
    
    
else:
    print("No courses available")
# Out:
# GET /courses/{courseId}/components
# Testing with course ID: 2b0e22fb-3c19-48a0-a48c-046c7211e9e9
# {'abbreviation': '0HM130',
#  'addresses': [],
#  'admissionRequirements': [{'language': 'nl-NL',
#                             'value': 'Je moet voldoen aan één van de '
#                                      'onderstaande verzamelingen met eisen\n'
#                                      '- Verzameling 1\n'
#                                      '- Bachelor of Science (BSc) afgerond\n'
#                                      '- Verzameling 2\n'
#                                      '- Schakelprogramma afgerond'},
#                            {'language': 'en-GB',
#                             'value': 'You must meet one of the following '
#                                      'collections of requirements\n'
#                                      '- Collection 1\n'
#                                      '- Completed Final examination Bsc '
#                                      'program\n'
#                                      '- Collection 2\n'
#                                      '- Completed Pre-Master'}],
#  'assessment': [],
#  'consumers': [{'alliances': [{'name': 'EWUU',
#                                'selection': False,
#                                'theme': '',
#                                'type': 'broadening',
#                                'visibleForOwnStudents': False}],
#                 'consumerKey': 'eduxchange'}],
#  'courseId': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#  'description': [{'language': 'nl-NL',
#                   'value': 'The course consists of 10 lectures.   \n'
#                            'The lectures cover core topics in cognition '
#                            '(representations, attention, memory, language, '
#                            'categorization, creativity and AI, and '
#                            'similarity). These lecture will be accompanied by '
#                            'weekly assignments where students experience basic '
#                            'experimental paradigms in cognitive psychology, '
#                            'such as the Simon Effect, Working Memory Tasks, '
#                            'and Similarity experiments. Students will perform '
#                            'these experiments, reflect upon their underlying '
#                            'mechanisms and link them to theories in the '
#                            'reading material, and translate the relevance of '
#                            'these mechanisms to facets of human-technology '
#                            'interaction. Lectures are also accompanied by '
#                            'applied assignments providing advice for a '
#                            '(hypothetical) behavioral insight team that used '
#                            'knowledge from cognitive psychology to address a '
#                            'societal problem.'},
#                  {'language': 'en-GB',
#                   'value': 'The course consists of 10 lectures.   \n'
#                            'The lectures cover core topics in cognition '
#                            '(representations, attention, memory, language, '
#                            'categorization, creativity and AI, and '
#                            'similarity). These lecture will be accompanied by '
#                            'weekly assignments where students experience basic '
#                            'experimental paradigms in cognitive psychology, '
#                            'such as the Simon Effect, Working Memory Tasks, '
#                            'and Similarity experiments. Students will perform '
#                            'these experiments, reflect upon their underlying '
#                            'mechanisms and link them to theories in the '
#                            'reading material, and translate the relevance of '
#                            'these mechanisms to facets of human-technology '
#                            'interaction. Lectures are also accompanied by '
#                            'applied assignments providing advice for a '
#                            '(hypothetical) behavioral insight team that used '
#                            'knowledge from cognitive psychology to address a '
#                            'societal problem.'}],
#  'duration': '',
#  'enrollment': [],
#  'ext': {},
#  'fieldsOfStudy': '',
#  'firstStartDate': '',
#  'learningOutcomes': [[{'language': 'nl-NL',
#                         'value': '\n'
#                                  'The goal of the course is to gain a further '
#                                  'understanding of the basic research '
#                                  'questions and methodologies of cognitive '
#                                  'science.  \n'
#                                  '\n'
#                                  '\n'
#                                  'After the course, students will be able to:\n'
#                                  '- interpret empirical findings in cognitive '
#                                  'science in light of theoretical ideas,\n'
#                                  '- interpret classical findings and paradigms '
#                                  'in cognitive science,\n'
#                                  '- explain empirical findings from different '
#                                  'theoretical perspectives,\n'
#                                  '- apply scientific knowledge in a technical '
#                                  'domain and for government policy,\n'
#                                  '- critically evaluate ongoing scientific '
#                                  'research.\n'
#                                  '\n'},
#                        {'language': 'en-GB',
#                         'value': '\n'
#                                  'The goal of the course is to gain a further '
#                                  'understanding of the basic research '
#                                  'questions and methodologies of cognitive '
#                                  'science.  \n'
#                                  '\n'
#                                  '\n'
#                                  'After the course, students will be able to:\n'
#                                  '- interpret empirical findings in cognitive '
#                                  'science in light of theoretical ideas,\n'
#                                  '- interpret classical findings and paradigms '
#                                  'in cognitive science,\n'
#                                  '- explain empirical findings from different '
#                                  'theoretical perspectives,\n'
#                                  '- apply scientific knowledge in a technical '
#                                  'domain and for government policy,\n'
#                                  '- critically evaluate ongoing scientific '
#                                  'research.\n'
#                                  '\n'}]],
#  'level': 'master',
#  'link': 'https://tueacc.osiris-student.nl/onderwijscatalogus/extern/cursus?cursusid=1642484&taal=nl',
#  'modeOfDelivery': [],
#  'name': [{'language': 'nl-NL', 'value': 'Advanced cognition'},
#           {'language': 'en-GB', 'value': 'Advanced cognition'}],
#  'otherCodes': [],
#  'primaryCode': {'code': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#                  'codeType': 'uuid'},
#  'qualificationRequirements': [],
#  'resources': [' No book. Articles and chapters are provided by the lecturer.'],
#  'studyLoad': {'studyLoadUnit': 'ects', 'value': 5},
#  'teachingLanguage': 'eng',
#  'validFrom': '',
#  'validTo': ''}

# %%
print("GET /programs")

headers = {
    "api-key": API_KEY
}

params = {
    "programType": "program"
}

url = f"{BASE_URL}/programs"
response = requests.get(url, headers=headers, params=params, timeout=TIMEOUT)

if response.status_code == 200:
    data = response.json()
    print(f"Success! Found {len(data.get("items", []))} programs")
    
    if data.get("items"):
        for i, program in enumerate(data["items"], 1):
            print(f"{i}. {program.get('name', 'N/A')} (ID: {program.get('programId', 'N/A')})")
            pprint(data["items"])
            break
else:
    print(f"Failed: {response.status_code} - {response.text}")
# Out:
# GET /programs
# Success! Found 10 programs
# 1. [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'}, {'language': 'en-GB', 'value': 'AI and Digital Innovation'}] (ID: 37406c06-bc5e-424b-a710-0175523a66d4)
# [{'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['nld']}],
#   'description': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#                   {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2024-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#            {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '37406c06-bc5e-424b-a710-0175523a66d4',
#                   'codeType': 'uuid'},
#   'programId': '37406c06-bc5e-424b-a710-0175523a66d4',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2023-09-15'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['nld']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Analytics for Transport and Mobility'},
#                   {'language': 'en-GB',
#                    'value': 'Analytics for Transport and Mobility'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2024-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL',
#             'value': 'Analytics for Transport and Mobility'},
#            {'language': 'en-GB',
#             'value': 'Analytics for Transport and Mobility'}],
#   'otherCodes': [],
#   'primaryCode': {'code': 'c0f724ea-6c03-4670-93cb-a9cc0908e2bc',
#                   'codeType': 'uuid'},
#   'programId': 'c0f724ea-6c03-4670-93cb-a9cc0908e2bc',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2023-09-15'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL', 'value': 'Applied Physics'},
#                   {'language': 'en-GB', 'value': 'Applied Physics'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL', 'value': 'Applied Physics'},
#            {'language': 'en-GB', 'value': 'Applied Physics'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9bd8-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9bd8-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Architecture, Building and Planning'},
#                   {'language': 'en-GB',
#                    'value': 'Architecture, Building and Planning'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL',
#             'value': 'Architecture, Building and Planning'},
#            {'language': 'en-GB',
#             'value': 'Architecture, Building and Planning'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9bd0-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9bd0-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Artificial Intelligence & Engineering Systems'},
#                   {'language': 'en-GB',
#                    'value': 'Artificial Intelligence & Engineering Systems'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL',
#             'value': 'Artificial Intelligence & Engineering Systems'},
#            {'language': 'en-GB',
#             'value': 'Artificial Intelligence & Engineering Systems'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9c50-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9c50-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2022-09-01'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Artificial Intelligence Engineering Systems E'},
#                   {'language': 'en-GB',
#                    'value': 'Artificial Intelligence Engineering Systems E'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL',
#             'value': 'Artificial Intelligence Engineering Systems E'},
#            {'language': 'en-GB',
#             'value': 'Artificial Intelligence Engineering Systems E'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9ba0-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9ba0-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Artificial Intelligence Engineering Systems W'},
#                   {'language': 'en-GB',
#                    'value': 'Artificial Intelligence Engineering Systems W'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL',
#             'value': 'Artificial Intelligence Engineering Systems W'},
#            {'language': 'en-GB',
#             'value': 'Artificial Intelligence Engineering Systems W'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9c00-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9c00-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10',
#   'validTo': '2025-08-31'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL', 'value': 'Automotive Technology'},
#                   {'language': 'en-GB', 'value': 'Automotive Technology'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL', 'value': 'Automotive Technology'},
#            {'language': 'en-GB', 'value': 'Automotive Technology'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9bb8-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9bb8-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_mandatory',
#                  'teachingLanguages': ['eng']}],
#   'description': [{'language': 'nl-NL', 'value': 'Automotive Technology'},
#                   {'language': 'en-GB', 'value': 'Automotive Technology'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2023-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL', 'value': 'Automotive Technology'},
#            {'language': 'en-GB', 'value': 'Automotive Technology'}],
#   'otherCodes': [],
#   'primaryCode': {'code': '0e0bba73-9a88-76e4-e063-6f2ba8c08759',
#                   'codeType': 'uuid'},
#   'programId': '0e0bba73-9a88-76e4-e063-6f2ba8c08759',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 180},
#   'timelineOverrides': [],
#   'validFrom': '2020-09-10'},
#  {'addresses': [],
#   'admissionRequirements': [],
#   'assessment': [],
#   'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                  'consentParticipationSTAP': 'permission_not_granted',
#                  'consumerKey': 'rio',
#                  'deficiency': 'no_deficiencies',
#                  'educationLocationCode': '114X284',
#                  'educationOffererCode': '114A734',
#                  'foreignPartners': [],
#                  'jointPartnerCodes': [],
#                  'propaedeuticPhase': 'no_propaedeutic_phase',
#                  'requirementsActivities': 'no_requirements',
#                  'studyChoiceCheck': 'study_choice_check_available',
#                  'teachingLanguages': ['nld']}],
#   'description': [{'language': 'nl-NL',
#                    'value': 'Behavioral and Social Computing'},
#                   {'language': 'en-GB',
#                    'value': 'Behavioral and Social Computing'}],
#   'duration': 'P1DT30H4S',
#   'enrollment': [],
#   'ext': {},
#   'firstStartDate': '2024-09-01',
#   'learningOutcomes': [[]],
#   'level': '',
#   'levelOfQualification': '',
#   'modeOfDelivery': [],
#   'modeOfStudy': 'full-time',
#   'name': [{'language': 'nl-NL', 'value': 'Behavioral and Social Computing'},
#            {'language': 'en-GB', 'value': 'Behavioral and Social Computing'}],
#   'otherCodes': [],
#   'primaryCode': {'code': 'deb7aa8c-9a9f-4555-bd10-0eb8338751f6',
#                   'codeType': 'uuid'},
#   'programId': 'deb7aa8c-9a9f-4555-bd10-0eb8338751f6',
#   'programType': 'program',
#   'qualificationAwarded': '',
#   'qualificationRequirements': [],
#   'resources': [],
#   'sector': 'university education',
#   'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#   'timelineOverrides': [],
#   'validFrom': '2023-09-15'}]

# %%
print("GET /programs/{programId}/offerings")

headers = {
    "api-key": API_KEY
}

params_list = {
    "programType": "program"
}

url = f"{BASE_URL}/programs"
response = requests.get(url, headers=headers, params=params_list, timeout=TIMEOUT)
data = response.json()

if data.get("items") and len(data["items"]) > 0:
    program_id = data["items"][0]["programId"]
    print(f"Testing with program ID: {program_id}")
    pprint(data["items"][0])
    
else:
    print("No programs available")
# Out:
# GET /programs/{programId}/offerings
# Testing with program ID: 37406c06-bc5e-424b-a710-0175523a66d4
# {'addresses': [],
#  'admissionRequirements': [],
#  'assessment': [],
#  'consumers': [{'acceleratedRoute': 'no_accelerated_route',
#                 'consentParticipationSTAP': 'permission_not_granted',
#                 'consumerKey': 'rio',
#                 'deficiency': 'no_deficiencies',
#                 'educationLocationCode': '114X284',
#                 'educationOffererCode': '114A734',
#                 'foreignPartners': [],
#                 'jointPartnerCodes': [],
#                 'propaedeuticPhase': 'no_propaedeutic_phase',
#                 'requirementsActivities': 'no_requirements',
#                 'studyChoiceCheck': 'study_choice_check_available',
#                 'teachingLanguages': ['nld']}],
#  'description': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#                  {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#  'duration': 'P1DT30H4S',
#  'enrollment': [],
#  'ext': {},
#  'firstStartDate': '2024-09-01',
#  'learningOutcomes': [[]],
#  'level': '',
#  'levelOfQualification': '',
#  'modeOfDelivery': [],
#  'modeOfStudy': 'full-time',
#  'name': [{'language': 'nl-NL', 'value': 'AI and Digital Innovation'},
#           {'language': 'en-GB', 'value': 'AI and Digital Innovation'}],
#  'otherCodes': [],
#  'primaryCode': {'code': '37406c06-bc5e-424b-a710-0175523a66d4',
#                  'codeType': 'uuid'},
#  'programId': '37406c06-bc5e-424b-a710-0175523a66d4',
#  'programType': 'program',
#  'qualificationAwarded': '',
#  'qualificationRequirements': [],
#  'resources': [],
#  'sector': 'university education',
#  'studyLoad': {'studyLoadUnit': 'ects', 'value': 120},
#  'timelineOverrides': [],
#  'validFrom': '2023-09-15'}

# %%
print("GET /components/{componentId}/offerings")

headers = {
    "api-key": API_KEY
}

params_courses = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/courses"
response = requests.get(url, headers=headers, params=params_courses, timeout=TIMEOUT)
courses_data = response.json()

if courses_data.get("items") and len(courses_data["items"]) > 0:
    course_id = courses_data["items"][0]["courseId"]
    
    url = f"{BASE_URL}/courses/{course_id}/components"
    response = requests.get(url, headers=headers, timeout=TIMEOUT)
    components_data = response.json()
    
    if components_data.get("items") and len(components_data["items"]) > 0:
        component_id = components_data["items"][0]["componentId"]
        print(f"Testing with component ID: {component_id}")
        pprint(components_data["items"][0])        

    else:
        print("No components available")
else:
    print("No courses available")
# Out:
# GET /components/{componentId}/offerings
# Testing with component ID: 45bf0bde-b955-47ee-a95f-d3a3aadf7895
# {'abbreviation': 'PRODUCT_07',
#  'addresses': [],
#  'assessment': [{'language': 'nl-NL', 'value': 'Eindtoets'},
#                 {'language': 'en-GB', 'value': 'Final examination'}],
#  'componentId': '45bf0bde-b955-47ee-a95f-d3a3aadf7895',
#  'componentType': 'test',
#  'consumers': [],
#  'course': '2b0e22fb-3c19-48a0-a48c-046c7211e9e9',
#  'description': [],
#  'duration': None,
#  'enrollment': [],
#  'ext': {},
#  'learningOutcomes': [],
#  'modeOfDelivery': [],
#  'name': [{'language': 'nl-NL', 'value': 'Final assignment'},
#           {'language': 'en-GB', 'value': 'Final assignment'}],
#  'organization': '257e5de3-22a8-4861-bb21-12e560f91c8e',
#  'otherCodes': [],
#  'primaryCode': {'code': '45bf0bde-b955-47ee-a95f-d3a3aadf7895',
#                  'codeType': 'uuid'},
#  'resources': [],
#  'teachingLanguage': 'eng'}

# %%
print("GET /offerings/{offeringId}")

headers = {
    "api-key": API_KEY
}

params_courses = {
    "consumer": CONSUMER,
    "alliances.name": ALLIANCE
}

url = f"{BASE_URL}/courses"
response = requests.get(url, headers=headers, params=params_courses, timeout=TIMEOUT)
courses_data = response.json()

if courses_data.get("items") and len(courses_data["items"]) > 0:
    course_id = courses_data["items"][0]["courseId"]
    
    url = f"{BASE_URL}/courses/{course_id}/offerings"
    response = requests.get(url, headers=headers, params=params_courses, timeout=TIMEOUT)
    offerings_data = response.json()
    
    if offerings_data.get("items") and len(offerings_data["items"]) > 0:
        offering_id = offerings_data["items"][0]["offeringId"]
        print(f"Testing with offering ID: {offering_id}")
        pprint(offerings_data["items"][0])

    else:
        print("No offerings available")
else:
    print("No courses available")
# Out:
# GET /offerings/{offeringId}
# Testing with offering ID: 5a535ac9-5ffa-4aee-8079-074dc4960362
# {'abbreviation': 'GS2',
#  'academicSession': {'academicSessionId': 'd8fb1aab-db44-49a1-92e9-1a5c4577bac4',
#                      'academicSessionType': 'period',
#                      'consumers': [],
#                      'endDate': '2026-02-01',
#                      'ext': {},
#                      'name': [{'language': 'nl-NL', 'value': 'Kwartiel 2'},
#                               {'language': 'en-GB', 'value': 'Quartile 2'}],
#                      'otherCodes': [],
#                      'primaryCode': {'code': 'd8fb1aab-db44-49a1-92e9-1a5c4577bac4',
#                                      'codeType': 'uuid'},
#                      'startDate': '2025-11-10'},
#  'addresses': [{'additional': [],
#                 'addressType': 'teaching',
#                 'city': 'Eindhoven',
#                 'countryCode': 'NL',
#                 'ext': {},
#                 'geoLocation ': {},
#                 'postalCode': '5612 AE',
#                 'street': 'Groene Loper',
#                 'streetNumber': '3'}],
#  'consumers': [{'alliances': [{'dateComment': 'E1 - Tu 5-6, Th 1-2',
#                                'enrollEndTime': '',
#                                'enrollStartTime': '',
#                                'enrollmentUrl': '',
#                                'name': 'ewuu'}],
#                 'consumerKey': 'eduxchange'}],
#  'description': [{'language': 'nl-NL', 'value': 'Kwartiel 2'},
#                  {'language': 'en-GB', 'value': 'Quartile 2'}],
#  'endDate': '2026-01-18',
#  'enrolledNumberStudents': 58,
#  'ext': {},
#  'link': '',
#  'minNumberStudents': 0,
#  'name': [{'language': 'nl-NL', 'value': 'Kwartiel 2'},
#           {'language': 'en-GB', 'value': 'Quartile 2'}],
#  'offeringId': '5a535ac9-5ffa-4aee-8079-074dc4960362',
#  'offeringType': 'course',
#  'otherCodes': [],
#  'pendingNumberStudents': 0,
#  'primaryCode': {'code': '5a535ac9-5ffa-4aee-8079-074dc4960362',
#                  'codeType': 'uuid'},
#  'resultExpected': True,
#  'startDate': '2025-11-10',
#  'teachingLanguage': 'eng'}
