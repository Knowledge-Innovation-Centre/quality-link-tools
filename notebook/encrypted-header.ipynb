# %% [markdown]
# # QualityLink encrypted header
#
# Demo of <https://specs.quality-link.eu/data_exchange.html#access-control-header> in practice
#
# ## Part 1: Setup - Install Required Libraries

# %%
# !pip3 install cryptography
# Out:
# Requirement already satisfied: cryptography in /usr/local/python/3.12.1/lib/python3.12/site-packages (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography) (2.23)

# %%
try:
    import os
    from datetime import datetime, timedelta
    from cryptography import x509
    from cryptography.x509.oid import NameOID, ExtensionOID
    from cryptography.hazmat.primitives import hashes, serialization
    from cryptography.hazmat.primitives.asymmetric import rsa, padding
    from cryptography.hazmat.backends import default_backend
    import hashlib
    import base64
    import json

    print("✅ Libraries imported successfully!")

except ImportError as e:
    print(f"Required module missing: {e.name}. Please install it before running the script.")
    exit(1)
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## Part 2: QL-Pipeline Generates
#
# This simulates QL-Pipeline creating their private/public key pair.
#
# The private key will NEVER be shared with providers.

# %%
# Generate private key (4096-bit RSA)

print("\nGenerating QL-Pipeline's private key (4096-bit RSA)...")
ql_private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=4096,
    backend=default_backend()
)

print(f"✅ Private key generated successfully: {ql_private_key}")
# Out:
# Generating QL-Pipeline's private key (4096-bit RSA)...
# ✅ Private key generated successfully: <cryptography.hazmat.bindings._rust.openssl.rsa.RSAPrivateKey object at 0x773278c177b0>

# %%
# Extract public key from private key, convert both to PEM

ql_public_key = ql_private_key.public_key()

private_pem = ql_private_key.private_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PrivateFormat.PKCS8,
    encryption_algorithm=serialization.NoEncryption()
)
public_pem = ql_public_key.public_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PublicFormat.SubjectPublicKeyInfo
)

print(f"\n🔐 Private key:\n{private_pem.decode()}\n\n")
print(f"🔑 Public key:\n{public_pem.decode()}\n\n")
# Out:
# 🔐 Private key:
# -----BEGIN PRIVATE KEY-----
# MIIJQwIBADANBgkqhkiG9w0BAQEFAASCCS0wggkpAgEAAoICAQCoZ/BNQ8ezyhRd
# mMw9d7n7uvpu4/QPTALLNtBoryZ/Lai/rezmmNfu9g1MRu28PybIQ9iy6BeCfojL
# TF0NdOuXVFS3R4mkF6F+j2g2+sm9qwUES9FsdKBbUvZrYNiCD6U1vEbsfSBGXrLP
# nYgMFFrYFEGpXuf6e0+L+snCKQAP6C6ylBL9lxOwcHot07H2jaQM1vEQnsBSjy1X
# 3yblUYFLSakPhizw78AqafAEMpy+5VVAuiqZZLlNJBGWf0L9qKCBR0t1W4GvnXA3
# YRcaXV11Gv7B6q2i7pFGxeGi/GVggqXgffI9+qZ3rGv5DbQ1uZKlP6zA0AywlWjI
# 3GNV9VGBxm0xxviTUc0xxpkB9vN+3AIMi+BiDAYazBcXYTBimcsvo8LE7xR9HZVD
# J5X4ViygNfA0a6hPi47Frh4qqu0eq14oQbe+8n1nAz6HQ7Q0Td5G9fWU8RD0gWey
# ZetrmEmOstkkZyMShv1qTlIVcT91txevlguhNvC2kMYaS9Ao0G4v8QZsBBqctJaT
# 7mDLPdL+ssVTvf2j7D869uZt0t47cY91eBxYrfVaUHu00cEVsRIVjO8zhKpJMVd5
# e0vJc4SYNmfGsC4TMMPsFGYKAv+stO35Ap1lzpw9ng6NUEzjDV13ZvdVfUgloJe6
# Rkq7c/EliVRXdI+nKpKp+QTqf1MfPwIDAQABAoICAAMsYOTIRrBdq752Nj8K8Mu+
# Ri9Co9TfEmqgqqEIJTosnV0KaM8fXocu1P6KIhCXbSmalT5FzXMp/8seQFCibwAO
# 9SSZ4uK0h4Mhg6pGAE5rX/fhs2udYW+DjmuBPWbAPGOR/2aVT3g3jPElJoJO36lb
# tFvvoUfEizHNH4BFZ9jzHCd+Fgow8jcXGGOhPE9s5YRQpMlBAB41Ql4WeFeNVa8a
# OfUn4A1BHYaA21FCtcg1i1Dh32guc8QbwCo0VV9xDhIcPFDU31GRA9xfSe+MhoLQ
# PT6Zp4swt8VReLTVXw8BOsv1/H4zfowZwg0acGS6G92WS2nmfizx4urC7NXTjMGq
# LPxxgzqAeUz92PTGwmGFb687KbQfeP43ylolTgUMXGQ3GGxBIX+SZk2fFW35ndBj
# pO+G5Siu6Wz/o697BuQmnl2c/8bBnuefedNJL0BMeZJgL7BoziYdNObBJz45oEz8
# nri6RQfwG3M3Pj1ydP0Twmj6VoQN6VIThAOQo2vCy/+eNbA8pcih7SW5wGVj33Us
# 3sx+4izdlqzRmROmi4y3+XbaGQabk51hVwu0YKVNK8YU9JiJstBVYW2t+bMn+wC9
# /ycfJvB4UYET/o/bF+cKsXLuYJ0Z235J4iN0ZxYJnFkHzsqqiBN+mX9oQurdP2/x
# RwI+gJnHyKvtNRI1XEQtAoIBAQDQs9PcAkW+4Z+JidmDhrk6It86yJp1+yRObIqL
# TT3P0C9ISbp8rDw3pe7FR9hhsrTH3CZryu2AF3fk4tHO5gDtCLwi+0sjANOlnxT3
# UXHEu/oX7sJeV44iCnT4cApuBY2qf+sTfdn5gLu6aS82oY75LewkTd+XvrSOsYSb
# jh7rb+euHI1vI6RPEFtXy1b56sCzSE7kikVLkQ8CbCqcSQx9adMgqBrwDfkBgkH5
# 0Xzir4DLxsUijlEfkx7YPBkmt7/uoEhs1s1ELdnhQSHATKtoqFTPffDKSsIhrjuB
# U6ziTjIMPoiI22zGHyTzD/Okr8u9Yhv0qMi+wPV4IEZQUOGNAoIBAQDOkkFVi86b
# 1yAIiCXHy+6iZLjY/U0yyvAQQa7Gz/zZ/UcDgRlTmxdhHjte38vUOk0n8daYG9f7
# Y7LFq2x5Xp28VoC9VFwG+WX+EdrGHm+gsGMZI4xBL9onmSI8x3uQoV4o64bD8lad
# 2ibikKTDUb9K45xLXp4wbsKHVJx2kyWpY0PUl1eEFrt3IfBDOaxFkvbQ0UFakpjG
# /L6wAr0uni5B+NkUARpRoyRxFByOCulVOkFog2PI3fgZJA4bV2i71QtkAUInIspM
# gDkFq8vf8BhViIDeWiwxTh+ztH4amANopouVj9p3OYyGSYCiROCgvyzNpjUm16qB
# d/Wkj2b55mL7AoIBAHBoCrm6t5oBp43Ko07F50m6soTUuuzEoV9j8pLovVwKgwzq
# OPkhQyWtx5aWBaNJPzlOB5uTJqwQ99BdoidPljwUslAdDPEDZvsTXZV/Vklh/Wea
# fzGU8sa+3xVYMyXi89RbJV/QLvDFN1dFg9pm1by70S4Ui1MNse4RCp1FxL2F/kC2
# vC6aActbwfbdXDErETL+xQ8usffrXyws2h5m8cUylDZIlImq3OzFHYfSHvNxF2up
# 2U+tW2AoOzq308wYt9VsmtWUM+Z+05URIX6TTNcHovZGnMQ306uUThRv3vPcrfQO
# Ujd0B3gGGj6X3uBalt+f0fLKXaTwBMX4jCaCCZkCggEBAL9DG8shT4Nrg/ViWdjM
# MX+a0qvWnIvS6sOijTj3ip4rrHzKI7ENgHAjlcUaYZd3A8lgWdksrqXMgdIUDrOx
# r0qarUifuzWZ5Z2A2pdlxuV5a8fy6gHRVKQlXVX5PaeEQbKRoI3868XsHuTYGDXg
# ksW8SRJf4QfnBaZX6SbAx7Y2eq90EUvz4E9F1TfpRmCE2pItrd02rs5PZh+B6bgo
# LZxX1GZ5Pu0nqK4qeOXrpG+NKNKkFNf+7aAZihY2sHp5n7pQj/e8dqKudh2SG4qU
# u3M2mFtIEnL0atXw4HGvHjjfO46XSyfo2PvdQoT8UR+E4u7mXYBBX1XQxFhBjo8D
# idECggEBAI2VgUZrtKxPUZzzfsCbm0jbFy9mbZoeo9BfiR8C6YGT1ATlybQjNjgd
# sHewOdKjkeqgfBXy6rgicNvePbT3stkaRKZmzizYIyQ+Vkg3RPs1EefST+PDOO26
# sYthvf++VRcoOXl104Zk6qIr/DfsJyOA6GL0DvJ9xOILuZnv6O4509KkvAyN1sE3
# UdyepobkFPyr5HUSqGgtknogLKt5Xv73VoUaWdn7BL5HPMTy2NXN5hzR0CiqWu8c
# msHcx06mKnQYh+6VW024t+P+Tau57a4Y8qs7WswlXZ9rXovdZNDrFsyC9OAIUJa7
# 9C4hvmZcLhZnfNA8RkclxUkzXp70xMk=
# -----END PRIVATE KEY-----
#
#
#
# 🔑 Public key:
# -----BEGIN PUBLIC KEY-----
# MIICIjANBgkqhkiG9w0BAQEFAAOCAg8AMIICCgKCAgEAqGfwTUPHs8oUXZjMPXe5
# +7r6buP0D0wCyzbQaK8mfy2ov63s5pjX7vYNTEbtvD8myEPYsugXgn6Iy0xdDXTr
# l1RUt0eJpBehfo9oNvrJvasFBEvRbHSgW1L2a2DYgg+lNbxG7H0gRl6yz52IDBRa
# 2BRBqV7n+ntPi/rJwikAD+guspQS/ZcTsHB6LdOx9o2kDNbxEJ7AUo8tV98m5VGB
# S0mpD4Ys8O/AKmnwBDKcvuVVQLoqmWS5TSQRln9C/aiggUdLdVuBr51wN2EXGl1d
# dRr+weqtou6RRsXhovxlYIKl4H3yPfqmd6xr+Q20NbmSpT+swNAMsJVoyNxjVfVR
# gcZtMcb4k1HNMcaZAfbzftwCDIvgYgwGGswXF2EwYpnLL6PCxO8UfR2VQyeV+FYs
# oDXwNGuoT4uOxa4eKqrtHqteKEG3vvJ9ZwM+h0O0NE3eRvX1lPEQ9IFnsmXra5hJ
# jrLZJGcjEob9ak5SFXE/dbcXr5YLoTbwtpDGGkvQKNBuL/EGbAQanLSWk+5gyz3S
# /rLFU739o+w/OvbmbdLeO3GPdXgcWK31WlB7tNHBFbESFYzvM4SqSTFXeXtLyXOE
# mDZnxrAuEzDD7BRmCgL/rLTt+QKdZc6cPZ4OjVBM4w1dd2b3VX1IJaCXukZKu3Px
# JYlUV3SPpyqSqfkE6n9THz8CAwEAAQ==
# -----END PUBLIC KEY-----

# %% [markdown]
# ## Part 3: provider A encrypts token with public key
#
# Provider A receives the public key via email/portal. They use it to encrypt a token.

# %%
# Simulate Provider A receiving the certificate

print(f"\n📧 Provider A receives aggreator_pub.pem")

pubkey = serialization.load_pem_public_key(public_pem)

secret = "SUPER-SECRET-TOKEN-4711"

ciphertext = base64.b64encode(pubkey.encrypt(
    secret.encode('utf-8'),
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
)).decode()

print(f"\nSecret: {secret}\nEncrypted: {ciphertext}")

manifest = {
    "meta": {
        "schac": "example.ac.at",
        "eterid": "AT4711",
        "deqarid": "DEQARINST0815"
    },
    "sources": [
        {
            "type": "ooapi",
            "path": "https://data.example.org/ooapi/v5/",
            "version": "5",
            "auth": {
                "type": "httpheader",
                "field": "X-API-Key",
                "value": ciphertext
            },
            "id": "eua-courses-virt",
            "name": "Courses offered on the Alliance's virtual campus"
        }
    ]
}

print(f"\nProvider includes this in manifest file, example:\n\n{json.dumps(manifest, indent=2)}")
# Out:
# 📧 Provider A receives aggreator_pub.pem
#
# Secret: SUPER-SECRET-TOKEN-4711
# Encrypted: ...
#
# Provider includes this in manifest file, example:
#
# {
#   "meta": {
#     "schac": "example.ac.at",
#     "eterid": "AT4711",
#     "deqarid": "DEQARINST0815"
#   },
#   "sources": [
#     {
#       "type": "ooapi",
#       "path": "https://data.example.org/ooapi/v5/",
#       "version": "5",
#       "auth": {
#         "type": "httpheader",
#         "field": "X-API-Key",
#         "value": "..."
#       },
#       "id": "eua-courses-virt",
#       "name": "Courses offered on the Alliance's virtual campus"
#     }
#   ]
# }

# %% [markdown]
# ## Part 4: QL-Pipeline decrypts provider secret
#
# QL-Pipeline wants to fetch courses from Provider A. Pipeline takes the encrypted value from the manifest and sends it back.

# %%
print(f"🔑 Encrypted data from manifest: {manifest['sources'][0]['auth']['value']}")

decrypted = ql_private_key.decrypt(
    base64.b64decode(manifest['sources'][0]['auth']['value']),
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
).decode()

print(f"💬 Cleartext: {decrypted}")
# Out:
# 🔑 Encrypted data from manifest: ...
# 💬 Cleartext: SUPER-SECRET-TOKEN-4711

# %% [markdown]
# ## Part 5: QL-Pipeline makes request for data
#
# With the decrypted secret, the QL-Pipeline makes a request with the expected HTTP header included. (The whole request is encrypted via HTTPS as usual.)

# %%
print("\n📡 HTTP request by QL-Pipeline → Provider A:")
print("   GET /api/courses HTTP/1.1")
print("   Host: provider-a.edu")
print(f"   {manifest['sources'][0]['auth']['field']}: {decrypted}")
# Out:
# 📡 HTTP request by QL-Pipeline → Provider A:
#    GET /api/courses HTTP/1.1
#    Host: provider-a.edu
#    X-API-Key: SUPER-SECRET-TOKEN-4711
