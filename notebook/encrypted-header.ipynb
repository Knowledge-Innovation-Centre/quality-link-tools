# %% [markdown]
# # QualityLink encrypted header
#
# Demo of <https://specs.quality-link.eu/data_exchange.html#access-control-header> in practice
#
# ## Part 1: Setup - Install Required Libraries

# %%
# %pip install cryptography
# Out:
# 570.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cryptography
#   Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.0_1/libexec/lib/python3.14/site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Cellar/jupyterlab/4.5.0_1/libexec/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography) (2.23)
# Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
# Installing collected packages: cryptography
# Successfully installed cryptography-46.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    import os
    from datetime import datetime, timedelta
    from cryptography import x509
    from cryptography.x509.oid import NameOID, ExtensionOID
    from cryptography.hazmat.primitives import hashes, serialization
    from cryptography.hazmat.primitives.asymmetric import rsa, padding
    from cryptography.hazmat.backends import default_backend
    import hashlib
    import base64
    import json

    print("✅ Libraries imported successfully!")

except ImportError as e:
    print(f"Required module missing: {e.name}. Please install it before running the script.")
    exit(1)
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## Part 2: QL-Pipeline Generates
#
# This simulates QL-Pipeline creating their private/public key pair.
#
# The private key will NEVER be shared with providers.

# %%
# Generate private key (4096-bit RSA)

print("\nGenerating QL-Pipeline's private key (4096-bit RSA)...")
ql_private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=4096,
    backend=default_backend()
)

print(f"✅ Private key generated successfully: {ql_private_key}")
# Out:
# Generating QL-Pipeline's private key (4096-bit RSA)...
# ✅ Private key generated successfully: <cryptography.hazmat.bindings._rust.openssl.rsa.RSAPrivateKey object at 0x7fe5e556c970>

# %%
# Extract public key from private key, convert both to PEM

ql_public_key = ql_private_key.public_key()

private_pem = ql_private_key.private_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PrivateFormat.PKCS8,
    encryption_algorithm=serialization.NoEncryption()
)
public_pem = ql_public_key.public_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PublicFormat.SubjectPublicKeyInfo
)

print(f"\n🔐 Private key:\n{private_pem.decode()}\n\n")
print(f"🔑 Public key:\n{public_pem.decode()}\n\n")
# Out:
# 🔐 Private key:
# -----BEGIN PRIVATE KEY-----
# MIIJRAIBADANBgkqhkiG9w0BAQEFAASCCS4wggkqAgEAAoICAQDHOHjH9Ae7MRcV
# tltY9368HJ+PSSeMFhUMVAHNze7d/0mOADgqTjBU7RrA4WBmnI/6rgBDy8wAHbqf
# QfLH//c9cf37W9q7cuPvPrckC+yiBRGunTNB5tvkygoGutHgd3wruPJbgCw3A43S
# CbGzyvlsHGqqOTe1LFOgTfMat7K2ob3M/7nP8myEKj9SqDZK7c6xfyXmeWjB40pb
# xjfL1R2RHlo/u/RwcDRI0U4RJUHjq2wFlycVeIKdfFeYgcf5bCDKprZwNAcxRDb0
# NsKfpNVYQk1MpXq29yt6hJOq1h7YgDXcUyxtCOj+eZ48LC0Ftp4VjO6/M2SkuVEx
# xqU3dmy7GUKjs0Lu4vV0Q66Aya6UKhlyRnBe2IQbZmcIIywQ/BUmHWXQGYXocXZP
# dXwwqrR1/LpmwR/mA+jr1uPDlEtj20vdXcFPyJnkO0IMDbi78Q+XVAWiPSEO2nDi
# PYRgHovb+0UappFA2ac1hDGsaaZL/gpssdI5N0V5Td/LNJjuRtR2uMqSe8DHKhyP
# foJDApAK0k3wv5y5+0l90o8fpdxxrttemtP60Lb76M1DgVk9uNbMkjSzMl26jZIC
# 3AT3qXmGeSxtT4IYTmwDNk4N+OarKrJxs4ghgAVVojRb3YwYD50ByiwfaLerbiWw
# kySLOltp4Et+q1DdknkfNUMHlkChpwIDAQABAoICAA38FFpw8nP9A7JV/T6XDRH2
# bmr4Byspx6t4YDIKwThbOdYahNbPa0wi4sxkZch+OAswWLtpnHXroFSapAjPGpN5
# I4uYDJg4/fAm9mM05RUQhwe7aEQ5iPkcB60mQyJfMNu+3WB39GKeQL/cR1moJ28j
# 5YbygksZA/vOTQD0oTp5yyGPWANVcLGsZ4qNXVZQMEC8fLQblLN7mZYsqXEJEkzE
# FTDBKG0WK01rR/AjLedl+qy/yhITRhP5DQsbHScQpJKlNkxVEqYuNC9bgrkDMKjD
# 6ro1KZKbcjVlBhqpcjvfcCh5vDYhOH3Ymrd9oGF0ys8XeBD68hcwHReB6sokaYhv
# DcqXlzxOgRT04qYYNsNbdTVdLfzd1MYim/bGplYHvjyflQqCf0/0KkpOTk5oIwQ7
# YJ3FBtAmb69AuqR0EZf4NAKuVwiPpuRy/sfgxI6haoI7ep22HaUygH0RVJzY9E8y
# RYRplVTLj/29GM8fSWAfk2i+4cndj3kFVPWriAK27+lfXJ1S/EoSkqKGBAUvcAgx
# QwIdpfwy7yrTAp2jCZB/WYeyzma4hXVQDAX28yRv2GqDWnMmd6q91fydOaVhbXBV
# CoZH4l8O1VvfAIyAhMr9u11GnNPdOJZbVAAmYJxRozCCdC/uKZX1Ervtv7G1UVyq
# 0u2U7BgU3h0coP5aZdEZAoIBAQDkRw2sAMyUiZvzwwYLchJzy6wTESTwuyfXMd2c
# bvgSfoa8Rc0rfWZT3PDhyc8A+W/0TVfpFsxocrDGInzlmamnxothI3TAsFJ1A3gD
# aABbZNElcqIpMXCZD0J3ZzYgXSjlDN5iLDdjpJr60WK6tUbBnRxupJFvJTZWw/2k
# yCs8gnh7pC5+3+fEan9so4+UP/mea2Vy9xwtlynKeZgRci/mi6NDFwC8KweD3NWI
# FMRP6T5RVcjyOPFyoKRSLPQQv+8rhAZ2llOryFrz2Qe7196zo66JA1nZsh+znW5l
# E8cRK3hVBsBYL16cQFkBInG6YreUYGS2hbktExYuK7FLxrLPAoIBAQDfahA0uxYp
# gZrTNgTAzdKU21kOmR+YSWJw2OIm9ydugxkkqAiFJnLXjgwMYxLtSgqaD3P5B3LZ
# i1aA+KJDoORrjrscUq7kqcP5NBiWL31mziglymKrfwdVvMviLWcdzvrWhVKovSjL
# sHQGTIyQjw96Rp8f5ZRz/4JiiNdpYbvyxmM4q9HT44M6JBOKECi8O6pobnkfSium
# Y9pS2Rb4pn3w0f8oGXyvn1tIn9p1Evu72U7w4atY43kkQDj+S/Jl2L0IVKoLjOwp
# Fb+OI+t/LUOvfaoniS1ePPnIgfpjJJ0aoLd4DnObOsAjPWbm3Ji0zbXuWBbujSb1
# O6JRvAz0k7mpAoIBAQC+Oiu9ewkAes/3yTv/S7buwfoKBY5oAT5JCKfpFVwqZT+4
# It6/cAdWuVYOgdK7uCFATzeD6Ni77V88LT8xQeTsB/rcHuTLMeP02Mgo5oDtqEzV
# TPqvIyD2m43C3MJxI9DRVvD2lGwv39q6SsRgXHGzJE6uMPt0yGjI0xhKOfg1u2/V
# cNLCLaoAttKq4H3kh49nIY3vyNa1czODI+LCHwqlrxWE8eVN6PmhO+TBOrUA9phU
# xQzoNOWXpSBpzkYwsxEGjUWpisn868BHVkMomNJflnX6fU1hqRrb3cRB/MI1n6ju
# Ces9UXQg90p0NJTbQipDPjSPGU5frnkcTpK3V8RnAoIBAQCNG59qvrOLualBN8Ae
# yqDzlesU1k/nTopXfhSwya/lE/ZgeaUP/C3SyYwAkt7Ucsxpa9My+apnjqMvSFqs
# XkWHTZoOlIaUNElr76SLzyjkMteWrtJNQSkv1NPtYgHcCOvTbFe97eODa0qM4/Jw
# J3t+HnbInad68Gm4tHdhvvIHr5fhplwb+Xnb0gdpTzV7VjAWT5g+1Ajnye+OHkFt
# ATNQVEJVYGupPPxZzWUcRsYqamF6sP4ZYWsVI18b9nn+K7uRNHBGZVaPyIW5UCSg
# qcUzZSqAWBsIh3i4VKgB0JFNzS60LGSGKcBLQa/ppnDo2XjMNmUdfJebknO+Lgj8
# vQUpAoIBAQCOjXP2pbHhZZC1KI8+ij5UJ3Va9LPCEG4sr1HaVqT7d8Y0ez6uzBG+
# YmNsAegms9HjtXR0TsrtG6Wdy4GzxDkTn+sJ30LfVwIjTwSrm5tzr1bm41NkVEfy
# Ingg/1E3ElfWJB+MT+Kpwhg9G//OwKsEiffDXEDa6hieNOHJ/TrhIpXuE9ucsK5e
# In53TnYRIMLF/C3PCSqAix51FxbFycJvIQTOR5IHmItK3ahwxkf2+2z9xcYo+AxJ
# HGj7BNHH5Pd8jfJfgSbDRKVgthpvTBXQeknBHRHir/kh7lt9hRc5NxL/zfsJx16c
# 0w3Sxea9BJ0al4Qmof7PAMqYMwaJk2vl
# -----END PRIVATE KEY-----
#
#
#
# 🔑 Public key:
# -----BEGIN PUBLIC KEY-----
# MIICIjANBgkqhkiG9w0BAQEFAAOCAg8AMIICCgKCAgEAxzh4x/QHuzEXFbZbWPd+
# vByfj0knjBYVDFQBzc3u3f9JjgA4Kk4wVO0awOFgZpyP+q4AQ8vMAB26n0Hyx//3
# PXH9+1vau3Lj7z63JAvsogURrp0zQebb5MoKBrrR4Hd8K7jyW4AsNwON0gmxs8r5
# bBxqqjk3tSxToE3zGreytqG9zP+5z/JshCo/Uqg2Su3OsX8l5nloweNKW8Y3y9Ud
# kR5aP7v0cHA0SNFOESVB46tsBZcnFXiCnXxXmIHH+Wwgyqa2cDQHMUQ29DbCn6TV
# WEJNTKV6tvcreoSTqtYe2IA13FMsbQjo/nmePCwtBbaeFYzuvzNkpLlRMcalN3Zs
# uxlCo7NC7uL1dEOugMmulCoZckZwXtiEG2ZnCCMsEPwVJh1l0BmF6HF2T3V8MKq0
# dfy6ZsEf5gPo69bjw5RLY9tL3V3BT8iZ5DtCDA24u/EPl1QFoj0hDtpw4j2EYB6L
# 2/tFGqaRQNmnNYQxrGmmS/4KbLHSOTdFeU3fyzSY7kbUdrjKknvAxyocj36CQwKQ
# CtJN8L+cuftJfdKPH6Xcca7bXprT+tC2++jNQ4FZPbjWzJI0szJduo2SAtwE96l5
# hnksbU+CGE5sAzZODfjmqyqycbOIIYAFVaI0W92MGA+dAcosH2i3q24lsJMkizpb
# aeBLfqtQ3ZJ5HzVDB5ZAoacCAwEAAQ==
# -----END PUBLIC KEY-----

# %% [markdown]
# ## Part 3: provider A encrypts token with public key
#
# Provider A receives the public key via email/portal. They use it to encrypt a token.
#
# Equivalent with openssl-pkeyutl(1):
#
# ```
# echo SUPER-SECRET-TOKEN-4711 | openssl pkeyutl -encrypt -pkeyopt rsa_padding_mode:oaep -pubin -inkey aggregator_pub.pem | base64
# ```

# %%
# Simulate Provider A receiving the certificate

print(f"\n📧 Provider A receives aggreator_pub.pem")

pubkey = serialization.load_pem_public_key(public_pem)

secret = "SUPER-SECRET-TOKEN-4711"

ciphertext = base64.b64encode(pubkey.encrypt(
    secret.encode('utf-8'),
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA1()),
        algorithm=hashes.SHA1(),
        label=None
    )
)).decode()

print(f"\nSecret: {secret}\nEncrypted: {ciphertext}")

manifest = {
    "meta": {
        "schac": "example.ac.at",
        "eterid": "AT4711",
        "deqarid": "DEQARINST0815"
    },
    "sources": [
        {
            "type": "ooapi",
            "path": "https://data.example.org/ooapi/v5/",
            "version": "5",
            "auth": {
                "type": "httpheader",
                "field": "X-API-Key",
                "value": ciphertext
            },
            "id": "eua-courses-virt",
            "name": "Courses offered on the Alliance's virtual campus"
        }
    ]
}

print(f"\nProvider includes this in manifest file, example:\n\n{json.dumps(manifest, indent=2)}")
# Out:
# 📧 Provider A receives aggreator_pub.pem
#
# Secret: SUPER-SECRET-TOKEN-4711
# Encrypted: ...
#
# Provider includes this in manifest file, example:
#
# {
#   "meta": {
#     "schac": "example.ac.at",
#     "eterid": "AT4711",
#     "deqarid": "DEQARINST0815"
#   },
#   "sources": [
#     {
#       "type": "ooapi",
#       "path": "https://data.example.org/ooapi/v5/",
#       "version": "5",
#       "auth": {
#         "type": "httpheader",
#         "field": "X-API-Key",
#         "value": "..."
#       },
#       "id": "eua-courses-virt",
#       "name": "Courses offered on the Alliance's virtual campus"
#     }
#   ]
# }

# %% [markdown]
# ## Part 4: QL-Pipeline decrypts provider secret
#
# QL-Pipeline wants to fetch courses from Provider A. Pipeline takes the encrypted value from the manifest and sends it back.
#
# Equivalent with openssl-pkeyutl(1):
#
# ```
# echo $ENCRYPTED_VALUE | base64 -d | openssl pkeyutl -decrypt -inkey aggregator_priv.pem -pkeyopt rsa_padding_mode:oaep
# ```

# %%
encrypted = manifest['sources'][0]['auth']['value']

print(f"🔑 Encrypted data from manifest: {encrypted}")

decrypted = ql_private_key.decrypt(
    base64.b64decode(encrypted),
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA1()),
        algorithm=hashes.SHA1(),
        label=None
    )
).decode()

print(f"💬 Cleartext: {decrypted}")
# Out:
# 🔑 Encrypted data from manifest: ...
# 💬 Cleartext: SUPER-SECRET-TOKEN-4711

# %% [markdown]
# ## Part 5: QL-Pipeline makes request for data
#
# With the decrypted secret, the QL-Pipeline makes a request with the expected HTTP header included. (The whole request is encrypted via HTTPS as usual.)

# %%
print("\n📡 HTTP request by QL-Pipeline → Provider A:")
print("   GET /api/courses HTTP/1.1")
print("   Host: provider-a.edu")
print(f"   {manifest['sources'][0]['auth']['field']}: {decrypted}")
# Out:
# 📡 HTTP request by QL-Pipeline → Provider A:
#    GET /api/courses HTTP/1.1
#    Host: provider-a.edu
#    X-API-Key: SUPER-SECRET-TOKEN-4711
